# %% [markdown]
# ### This kernel is forked from [this wonderful kernel](https://www.kaggle.com/braquino/5-fold-lstm-attention-fully-commented-0-694) by Bruno Aquino. I have just stacked the recurrent layers together. Additionally, I have done some feature engineering based on time series entropy and fractal dimension. This achieves an LB score of 0.699.
#
# Feature Engineering : [Raphael Vallat's entropy repository](https://github.com/raphaelvallat/entropy/blob/master/entropy/utils.py)

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import sys
sys.path.append('..')
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import *
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
from keras import activations
from keras import regularizers
from keras import initializers
from keras import constraints
from sklearn.preprocessing import MinMaxScaler
from numba import jit
from math import log, floor
from sklearn.neighbors import KDTree
from scipy.signal import periodogram, welch
from keras.engine import Layer
from keras.engine import InputSpec
from keras.objectives import categorical_crossentropy
from keras.objectives import sparse_categorical_crossentropy
# import gplearn
# from gplearn.genetic import SymbolicTransformer
# from gplearn.functions import make_function
import utils

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../data/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../data/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [06:46<00:00,  3.50it/s]
# 100%|██████████| 1452/1452 [06:34<00:00,  3.57it/s]

# %%
def petrosian_fd(x):
    """Petrosian fractal dimension.
    Parameters
    ----------
    x : list or np.array
        One dimensional time series
    Returns
    -------
    pfd : float
        Petrosian fractal dimension
    Notes
    -----
    The Petrosian algorithm can be used to provide a fast computation of
    the FD of a signal by translating the series into a binary sequence.
    The Petrosian fractal dimension of a time series :math:`x` is defined by:
    .. math:: \dfrac{log_{10}(N)}{log_{10}(N) +
       log_{10}(\dfrac{N}{N+0.4N_{\Delta}})}
    where :math:`N` is the length of the time series, and
    :math:`N_{\Delta}` is the number of sign changes in the binary sequence.
    Original code from the pyrem package by Quentin Geissmann.
    References
    ----------
    .. [1] A. Petrosian, Kolmogorov complexity of finite sequences and
       recognition of different preictal EEG patterns, in , Proceedings of the
       Eighth IEEE Symposium on Computer-Based Medical Systems, 1995,
       pp. 212-217.
    .. [2] Goh, Cindy, et al. "Comparison of fractal dimension algorithms for
       the computation of EEG biomarkers for dementia." 2nd International
       Conference on Computational Intelligence in Medicine and Healthcare
       (CIMED2005). 2005.
    Examples
    --------
    Petrosian fractal dimension.
        >>> import numpy as np
        >>> from entropy import petrosian_fd
        >>> np.random.seed(123)
        >>> x = np.random.rand(100)
        >>> print(petrosian_fd(x))
            1.0505
    """
    n = len(x)
    # Number of sign changes in the first derivative of the signal
    diff = np.ediff1d(x)
    N_delta = (diff[1:-1] * diff[0:-2] < 0).sum()
    return np.log10(n) / (np.log10(n) + np.log10(n / (n + 0.4 * N_delta)))


def katz_fd(x):
    """Katz Fractal Dimension.
    Parameters
    ----------
    x : list or np.array
        One dimensional time series
    Returns
    -------
    kfd : float
        Katz fractal dimension
    Notes
    -----
    The Katz Fractal dimension is defined by:
    .. math:: FD_{Katz} = \dfrac{log_{10}(n)}{log_{10}(d/L)+log_{10}(n)}
    where :math:`L` is the total length of the time series and :math:`d`
    is the Euclidean distance between the first point in the
    series and the point that provides the furthest distance
    with respect to the first point.
    Original code from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort.
    References
    ----------
    .. [1] Esteller, R. et al. (2001). A comparison of waveform fractal
           dimension algorithms. IEEE Transactions on Circuits and Systems I:
           Fundamental Theory and Applications, 48(2), 177-183.
    .. [2] Goh, Cindy, et al. "Comparison of fractal dimension algorithms for
           the computation of EEG biomarkers for dementia." 2nd International
           Conference on Computational Intelligence in Medicine and Healthcare
           (CIMED2005). 2005.
    Examples
    --------
    Katz fractal dimension.
        >>> import numpy as np
        >>> from entropy import katz_fd
        >>> np.random.seed(123)
        >>> x = np.random.rand(100)
        >>> print(katz_fd(x))
            5.1214
    """
    x = np.array(x)
    dists = np.abs(np.ediff1d(x))
    ll = dists.sum()
    ln = np.log10(np.divide(ll, dists.mean()))
    aux_d = x - x[0]
    d = np.max(np.abs(aux_d[1:]))
    return np.divide(ln, np.add(ln, np.log10(np.divide(d, ll))))

@jit('UniTuple(float64, 2)(float64[:], float64[:])', nopython=True)
def _linear_regression(x, y):
    """Fast linear regression using Numba.
    Parameters
    ----------
    x, y : ndarray, shape (n_times,)
        Variables
    Returns
    -------
    slope : float
        Slope of 1D least-square regression.
    intercept : float
        Intercept
    """
    n_times = x.size
    sx2 = 0
    sx = 0
    sy = 0
    sxy = 0
    for j in range(n_times):
        sx2 += x[j] ** 2
        sx += x[j]
        sxy += x[j] * y[j]
        sy += y[j]
    den = n_times * sx2 - (sx ** 2)
    num = n_times * sxy - sx * sy
    slope = num / den
    intercept = np.mean(y) - slope * np.mean(x)
    return slope, intercept


@jit('i8[:](f8, f8, f8)', nopython=True)
def _log_n(min_n, max_n, factor):
    """
    Creates a list of integer values by successively multiplying a minimum
    value min_n by a factor > 1 until a maximum value max_n is reached.
    Used for detrended fluctuation analysis (DFA).
    Function taken from the nolds python package
    (https://github.com/CSchoel/nolds) by Christopher Scholzel.
    Parameters
    ----------
    min_n (float):
        minimum value (must be < max_n)
    max_n (float):
        maximum value (must be > min_n)
    factor (float):
       factor used to increase min_n (must be > 1)
    Returns
    -------
    list of integers:
        min_n, min_n * factor, min_n * factor^2, ... min_n * factor^i < max_n
        without duplicates
    """
    max_i = int(floor(log(1.0 * max_n / min_n) / log(factor)))
    ns = [min_n]
    for i in range(max_i + 1):
        n = int(floor(min_n * (factor ** i)))
        if n > ns[-1]:
            ns.append(n)
    return np.array(ns, dtype=np.int64)

@jit('float64(float64[:], int32)')
def _higuchi_fd(x, kmax):
    """Utility function for `higuchi_fd`.
    """
    n_times = x.size
    lk = np.empty(kmax)
    x_reg = np.empty(kmax)
    y_reg = np.empty(kmax)
    for k in range(1, kmax + 1):
        lm = np.empty((k,))
        for m in range(k):
            ll = 0
            n_max = floor((n_times - m - 1) / k)
            n_max = int(n_max)
            for j in range(1, n_max):
                ll += abs(x[m + j * k] - x[m + (j - 1) * k])
            ll /= k
            ll *= (n_times - 1) / (k * n_max)
            lm[m] = ll
        # Mean of lm
        m_lm = 0
        for m in range(k):
            m_lm += lm[m]
        m_lm /= k
        lk[k - 1] = m_lm
        x_reg[k - 1] = log(1. / k)
        y_reg[k - 1] = log(m_lm)
    higuchi, _ = _linear_regression(x_reg, y_reg)
    return higuchi


def higuchi_fd(x, kmax=10):
    """Higuchi Fractal Dimension.
    Parameters
    ----------
    x : list or np.array
        One dimensional time series
    kmax : int
        Maximum delay/offset (in number of samples).
    Returns
    -------
    hfd : float
        Higuchi Fractal Dimension
    Notes
    -----
    Original code from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort.
    The `higuchi_fd` function uses Numba to speed up the computation.
    References
    ----------
    .. [1] Higuchi, Tomoyuki. "Approach to an irregular time series on the
       basis of the fractal theory." Physica D: Nonlinear Phenomena 31.2
       (1988): 277-283.
    Examples
    --------
    Higuchi Fractal Dimension
        >>> import numpy as np
        >>> from entropy import higuchi_fd
        >>> np.random.seed(123)
        >>> x = np.random.rand(100)
        >>> print(higuchi_fd(x))
            2.051179
    """
    x = np.asarray(x, dtype=np.float64)
    kmax = int(kmax)
    return _higuchi_fd(x, kmax)

# %%
def _embed(x, order=3, delay=1):
    """Time-delay embedding.
    Parameters
    ----------
    x : 1d-array, shape (n_times)
        Time series
    order : int
        Embedding dimension (order)
    delay : int
        Delay.
    Returns
    -------
    embedded : ndarray, shape (n_times - (order - 1) * delay, order)
        Embedded time-series.
    """
    N = len(x)
    if order * delay > N:
        raise ValueError("Error: order * delay should be lower than x.size")
    if delay < 1:
        raise ValueError("Delay has to be at least 1.")
    if order < 2:
        raise ValueError("Order has to be at least 2.")
    Y = np.zeros((order, N - (order - 1) * delay))
    for i in range(order):
        Y[i] = x[i * delay:i * delay + Y.shape[1]]
    return Y.T

all = ['perm_entropy', 'spectral_entropy', 'svd_entropy', 'app_entropy',
       'sample_entropy']


def perm_entropy(x, order=3, delay=1, normalize=False):
    """Permutation Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int
        Order of permutation entropy
    delay : int
        Time delay
    normalize : bool
        If True, divide by log2(order!) to normalize the entropy between 0
        and 1. Otherwise, return the permutation entropy in bit.
    Returns
    -------
    pe : float
        Permutation Entropy
    Notes
    -----
    The permutation entropy is a complexity measure for time-series first
    introduced by Bandt and Pompe in 2002 [1]_.
    The permutation entropy of a signal :math:`x` is defined as:
    .. math:: H = -\sum p(\pi)log_2(\pi)
    where the sum runs over all :math:`n!` permutations :math:`\pi` of order
    :math:`n`. This is the information contained in comparing :math:`n`
    consecutive values of the time series. It is clear that
    :math:`0 ≤ H (n) ≤ log_2(n!)` where the lower bound is attained for an
    increasing or decreasing sequence of values, and the upper bound for a
    completely random system where all :math:`n!` possible permutations appear
    with the same probability.
    The embedded matrix :math:`Y` is created by:
    .. math:: y(i)=[x_i,x_{i+delay}, ...,x_{i+(order-1) * delay}]
    .. math:: Y=[y(1),y(2),...,y(N-(order-1))*delay)]^T
    References
    ----------
    .. [1] Bandt, Christoph, and Bernd Pompe. "Permutation entropy: a
           natural complexity measure for time series." Physical review letters
           88.17 (2002): 174102.
    Examples
    --------
    1. Permutation entropy with order 2
        >>> from entropy import perm_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value in bit between 0 and log2(factorial(order))
        >>> print(perm_entropy(x, order=2))
            0.918
    2. Normalized permutation entropy with order 3
        >>> from entropy import perm_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value comprised between 0 and 1.
        >>> print(perm_entropy(x, order=3, normalize=True))
            0.589
    """
    x = np.array(x)
    ran_order = range(order)
    hashmult = np.power(order, ran_order)
    # Embed x and sort the order of permutations
    sorted_idx = _embed(x, order=order, delay=delay).argsort(kind='quicksort')
    # Associate unique integer to each permutations
    hashval = (np.multiply(sorted_idx, hashmult)).sum(1)
    # Return the counts
    _, c = np.unique(hashval, return_counts=True)
    # Use np.true_divide for Python 2 compatibility
    p = np.true_divide(c, c.sum())
    pe = -np.multiply(p, np.log2(p)).sum()
    if normalize:
        pe /= np.log2(factorial(order))
    return pe


def spectral_entropy(x, sf, method='fft', nperseg=None, normalize=False):
    """Spectral Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    sf : float
        Sampling frequency
    method : str
        Spectral estimation method ::
        'fft' : Fourier Transform (via scipy.signal.periodogram)
        'welch' : Welch periodogram (via scipy.signal.welch)
    nperseg : str or int
        Length of each FFT segment for Welch method.
        If None, uses scipy default of 256 samples.
    normalize : bool
        If True, divide by log2(psd.size) to normalize the spectral entropy
        between 0 and 1. Otherwise, return the spectral entropy in bit.
    Returns
    -------
    se : float
        Spectral Entropy
    Notes
    -----
    Spectral Entropy is defined to be the Shannon Entropy of the Power
    Spectral Density (PSD) of the data:
    .. math:: H(x, sf) =  -\sum_{f=0}^{f_s/2} PSD(f) log_2[PSD(f)]
    Where :math:`PSD` is the normalised PSD, and :math:`f_s` is the sampling
    frequency.
    References
    ----------
    .. [1] Inouye, T. et al. (1991). Quantification of EEG irregularity by
       use of the entropy of the power spectrum. Electroencephalography
       and clinical neurophysiology, 79(3), 204-210.
    Examples
    --------
    1. Spectral entropy of a pure sine using FFT
        >>> from entropy import spectral_entropy
        >>> import numpy as np
        >>> sf, f, dur = 100, 1, 4
        >>> N = sf * duration # Total number of discrete samples
        >>> t = np.arange(N) / sf # Time vector
        >>> x = np.sin(2 * np.pi * f * t)
        >>> print(np.round(spectral_entropy(x, sf, method='fft'), 2)
            0.0
    2. Spectral entropy of a random signal using Welch's method
        >>> from entropy import spectral_entropy
        >>> import numpy as np
        >>> np.random.seed(42)
        >>> x = np.random.rand(3000)
        >>> print(spectral_entropy(x, sf=100, method='welch'))
            9.939
    3. Normalized spectral entropy
        >>> print(spectral_entropy(x, sf=100, method='welch', normalize=True))
            0.995
    """
    x = np.array(x)
    # Compute and normalize power spectrum
    if method == 'fft':
        _, psd = periodogram(x, sf)
    elif method == 'welch':
        _, psd = welch(x, sf, nperseg=nperseg)
    psd_norm = np.divide(psd, psd.sum())
    se = -np.multiply(psd_norm, np.log2(psd_norm)).sum()
    if normalize:
        se /= np.log2(psd_norm.size)
    return se


def svd_entropy(x, order=3, delay=1, normalize=False):
    """Singular Value Decomposition entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int
        Order of permutation entropy
    delay : int
        Time delay
    normalize : bool
        If True, divide by log2(order!) to normalize the entropy between 0
        and 1. Otherwise, return the permutation entropy in bit.
    Returns
    -------
    svd_e : float
        SVD Entropy
    Notes
    -----
    SVD entropy is an indicator of the number of eigenvectors that are needed
    for an adequate explanation of the data set. In other words, it measures
    the dimensionality of the data.
    The SVD entropy of a signal :math:`x` is defined as:
    .. math::
        H = -\sum_{i=1}^{M} \overline{\sigma}_i log_2(\overline{\sigma}_i)
    where :math:`M` is the number of singular values of the embedded matrix
    :math:`Y` and :math:`\sigma_1, \sigma_2, ..., \sigma_M` are the
    normalized singular values of :math:`Y`.
    The embedded matrix :math:`Y` is created by:
    .. math:: y(i)=[x_i,x_{i+delay}, ...,x_{i+(order-1) * delay}]
    .. math:: Y=[y(1),y(2),...,y(N-(order-1))*delay)]^T
    Examples
    --------
    1. SVD entropy with order 2
        >>> from entropy import svd_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value in bit between 0 and log2(factorial(order))
        >>> print(svd_entropy(x, order=2))
            0.762
    2. Normalized SVD entropy with order 3
        >>> from entropy import svd_entropy
        >>> x = [4, 7, 9, 10, 6, 11, 3]
        >>> # Return a value comprised between 0 and 1.
        >>> print(svd_entropy(x, order=3, normalize=True))
            0.687
    """
    x = np.array(x)
    mat = _embed(x, order=order, delay=delay)
    W = np.linalg.svd(mat, compute_uv=False)
    # Normalize the singular values
    W /= sum(W)
    svd_e = -np.multiply(W, np.log2(W)).sum()
    if normalize:
        svd_e /= np.log2(order)
    return svd_e


def _app_samp_entropy(x, order, metric='chebyshev', approximate=True):
    """Utility function for `app_entropy`` and `sample_entropy`.
    """
    _all_metrics = KDTree.valid_metrics
    if metric not in _all_metrics:
        raise ValueError('The given metric (%s) is not valid. The valid '
                         'metric names are: %s' % (metric, _all_metrics))
    phi = np.zeros(2)
    r = 0.2 * np.std(x, axis=-1, ddof=1)

    # compute phi(order, r)
    _emb_data1 = _embed(x, order, 1)
    if approximate:
        emb_data1 = _emb_data1
    else:
        emb_data1 = _emb_data1[:-1]
    count1 = KDTree(emb_data1, metric=metric).query_radius(emb_data1, r,
                                                           count_only=True
                                                           ).astype(np.float64)
    # compute phi(order + 1, r)
    emb_data2 = _embed(x, order + 1, 1)
    count2 = KDTree(emb_data2, metric=metric).query_radius(emb_data2, r,
                                                           count_only=True
                                                           ).astype(np.float64)
    if approximate:
        phi[0] = np.mean(np.log(count1 / emb_data1.shape[0]))
        phi[1] = np.mean(np.log(count2 / emb_data2.shape[0]))
    else:
        phi[0] = np.mean((count1 - 1) / (emb_data1.shape[0] - 1))
        phi[1] = np.mean((count2 - 1) / (emb_data2.shape[0] - 1))
    return phi


@jit('f8(f8[:], i4, f8)', nopython=True)
def _numba_sampen(x, mm=2, r=0.2):
    """
    Fast evaluation of the sample entropy using Numba.
    """
    n = x.size
    n1 = n - 1
    mm += 1
    mm_dbld = 2 * mm

    # Define threshold
    r *= x.std()

    # initialize the lists
    run = [0] * n
    run1 = run[:]
    r1 = [0] * (n * mm_dbld)
    a = [0] * mm
    b = a[:]
    p = a[:]

    for i in range(n1):
        nj = n1 - i

        for jj in range(nj):
            j = jj + i + 1
            if abs(x[j] - x[i]) < r:
                run[jj] = run1[jj] + 1
                m1 = mm if mm < run[jj] else run[jj]
                for m in range(m1):
                    a[m] += 1
                    if j < n1:
                        b[m] += 1
            else:
                run[jj] = 0
        for j in range(mm_dbld):
            run1[j] = run[j]
            r1[i + n * j] = run[j]
        if nj > mm_dbld - 1:
            for j in range(mm_dbld, nj):
                run1[j] = run[j]

    m = mm - 1

    while m > 0:
        b[m] = b[m - 1]
        m -= 1

    b[0] = n * n1 / 2
    a = np.array([float(aa) for aa in a])
    b = np.array([float(bb) for bb in b])
    p = np.true_divide(a, b)
    return -log(p[-1])


def app_entropy(x, order=2, metric='chebyshev'):
    """Approximate Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int (default: 2)
        Embedding dimension.
    metric : str (default: chebyshev)
        Name of the metric function used with
        :class:`~sklearn.neighbors.KDTree`. The list of available
        metric functions is given by: ``KDTree.valid_metrics``.
    Returns
    -------
    ae : float
        Approximate Entropy.
    Notes
    -----
    Original code from the mne-features package.
    Approximate entropy is a technique used to quantify the amount of
    regularity and the unpredictability of fluctuations over time-series data.
    Smaller values indicates that the data is more regular and predictable.
    The value of :math:`r` is set to :math:`0.2 * std(x)`.
    Code adapted from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort.
    References
    ----------
    .. [1] Richman, J. S. et al. (2000). Physiological time-series analysis
           using approximate entropy and sample entropy. American Journal of
           Physiology-Heart and Circulatory Physiology, 278(6), H2039-H2049.
    1. Approximate entropy with order 2.
        >>> from entropy import app_entropy
        >>> import numpy as np
        >>> np.random.seed(1234567)
        >>> x = np.random.rand(3000)
        >>> print(app_entropy(x, order=2))
            2.075
    """
    phi = _app_samp_entropy(x, order=order, metric=metric, approximate=True)
    return np.subtract(phi[0], phi[1])


def sample_entropy(x, order=2, metric='chebyshev'):
    """Sample Entropy.
    Parameters
    ----------
    x : list or np.array
        One-dimensional time series of shape (n_times)
    order : int (default: 2)
        Embedding dimension.
    metric : str (default: chebyshev)
        Name of the metric function used with KDTree. The list of available
        metric functions is given by: `KDTree.valid_metrics`.
    Returns
    -------
    se : float
        Sample Entropy.
    Notes
    -----
    Sample entropy is a modification of approximate entropy, used for assessing
    the complexity of physiological time-series signals. It has two advantages
    over approximate entropy: data length independence and a relatively
    trouble-free implementation. Large values indicate high complexity whereas
    smaller values characterize more self-similar and regular signals.
    Sample entropy of a signal :math:`x` is defined as:
    .. math:: H(x, m, r) = -log\dfrac{C(m + 1, r)}{C(m, r)}
    where :math:`m` is the embedding dimension (= order), :math:`r` is
    the radius of the neighbourhood (default = :math:`0.2 * std(x)`),
    :math:`C(m + 1, r)` is the number of embedded vectors of length
    :math:`m + 1` having a Chebyshev distance inferior to :math:`r` and
    :math:`C(m, r)` is the number of embedded vectors of length
    :math:`m` having a Chebyshev distance inferior to :math:`r`.
    Note that if metric == 'chebyshev' and x.size < 5000 points, then the
    sample entropy is computed using a fast custom Numba script. For other
    metric types or longer time-series, the sample entropy is computed using
    a code from the mne-features package by Jean-Baptiste Schiratti
    and Alexandre Gramfort (requires sklearn).
    References
    ----------
    .. [1] Richman, J. S. et al. (2000). Physiological time-series analysis
           using approximate entropy and sample entropy. American Journal of
           Physiology-Heart and Circulatory Physiology, 278(6), H2039-H2049.
    Examples
    --------
    1. Sample entropy with order 2.
        >>> from entropy import sample_entropy
        >>> import numpy as np
        >>> np.random.seed(1234567)
        >>> x = np.random.rand(3000)
        >>> print(sample_entropy(x, order=2))
            2.192
    2. Sample entropy with order 3 using the Euclidean distance.
        >>> from entropy import sample_entropy
        >>> import numpy as np
        >>> np.random.seed(1234567)
        >>> x = np.random.rand(3000)
        >>> print(sample_entropy(x, order=3, metric='euclidean'))
            2.725
    """
    x = np.asarray(x, dtype=np.float64)
    if metric == 'chebyshev' and x.size < 5000:
        return _numba_sampen(x, mm=order, r=0.2)
    else:
        phi = _app_samp_entropy(x, order=order, metric=metric,
                                approximate=False)
        return -np.log(np.divide(phi[1], phi[0]))

# %%
def entropy_and_fractal_dim(x):
    return [perm_entropy(x), svd_entropy(x), app_entropy(x), sample_entropy(x), petrosian_fd(x), katz_fd(x), higuchi_fd(x)]

# %%
signals = X.reshape((len(X), X.shape[1]*X.shape[2]))
features = []

for signal in signals:
    features.append(entropy_and_fractal_dim(signal))

# %%
features = np.array(features).reshape((len(features), 7))
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(features)
features = scaler.transform(features)

# %%
# model = Sequential([Dense(1, activation='sigmoid', input_shape=(7,))])
# model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
# model.fit(x, np.array(list(np.zeros((len(features_zero)))) + list(np.ones((len(features_one))))), epochs=1000)

# %%
# Weights and bias for logistic regression of entropy features
# weights = model.get_weights()[0]
# biases = model.get_weights()[1]

# %%
# print(weights)
# print(biases)

# %%
# e = 2.718281

# exp = make_function(function=lambda x: e**x, name='exp', arity=1)
# tanh = make_function(function=lambda x: (e**(2*x) - 1)/(e**(2*x) + 1), name='tanh', arity=1)

# %%
# function_set = ['add', 'sub', 'mul', 'div',
                # 'sqrt', 'log', 'abs', 'neg', 'inv',
                # 'max', 'min', exp, tanh]

# gp = SymbolicTransformer(generations=10, population_size=2000,
                         # hall_of_fame=100, n_components=50,
                         # function_set=function_set,
                         # parsimony_coefficient=0.0005,
                         # max_samples=0.9, verbose=1,
                         # random_state=0, n_jobs=3)

# gp.fit(features, np.array(list(np.zeros((len(features_zero)))) + list(np.ones((len(features_one))))))

# %%
# engineered_features = gp._programs

# for i in range(len(engineered_features)):
    # for engineered_feature in engineered_features[i]:
        # if engineered_feature != None:
            # print(engineered_feature)

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
np.save("features.npy",features)
# Out:
# (2904, 160, 57) (2904,)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape, feat_shape):
    inp = Input(shape=(input_shape[1], input_shape[2],))
    feat = Input(shape=(feat_shape[1],))

    bi_lstm = Bidirectional(CuDNNLSTM(128, return_sequences=True), merge_mode='concat')(inp)
    bi_gru = Bidirectional(CuDNNGRU(64, return_sequences=True), merge_mode='concat')(bi_lstm)
    
    attention = Attention(input_shape[1])(bi_gru)
    
    x = concatenate([attention, feat], axis=1)
    x = Dense(64, activation="relu")(x)
    x = Dense(1, activation="sigmoid")(x)
    
    model = Model(inputs=[inp, feat], outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_feat, train_y, val_X, val_feat, val_y = X[train_idx], features[train_idx], y[train_idx], X[val_idx], features[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape, features.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit([train_X, train_feat], train_y, batch_size=128, epochs=50, validation_data=([val_X, val_feat], val_y), callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict([val_X, val_feat], batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 6s 3ms/step - loss: 0.4213 - matthews_correlation: 0.0062 - val_loss: 0.2417 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 2s 678us/step - loss: 0.2408 - matthews_correlation: 0.0000e+00 - val_loss: 0.2386 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 2s 674us/step - loss: 0.2326 - matthews_correlation: 0.0000e+00 - val_loss: 0.2334 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 2s 673us/step - loss: 0.2231 - matthews_correlation: 0.0000e+00 - val_loss: 0.2255 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2322/2322 [==============================] - 2s 679us/step - loss: 0.2091 - matthews_correlation: 0.0000e+00 - val_loss: 0.2086 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2322/2322 [==============================] - 2s 676us/step - loss: 0.2043 - matthews_correlation: 0.0118 - val_loss: 0.2068 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2322/2322 [==============================] - 2s 673us/step - loss: 0.1989 - matthews_correlation: 0.0135 - val_loss: 0.1868 - val_matthews_correlation: 0.1583
#
# Epoch 00007: val_matthews_correlation improved from 0.00000 to 0.15834, saving model to weights_0.h5
# Epoch 8/50
# 2322/2322 [==============================] - 2s 679us/step - loss: 0.1739 - matthews_correlation: 0.2546 - val_loss: 0.1702 - val_matthews_correlation: 0.2930
#
# Epoch 00008: val_matthews_correlation improved from 0.15834 to 0.29297, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 2s 683us/step - loss: 0.1459 - matthews_correlation: 0.3991 - val_loss: 0.1307 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.29297
# Epoch 10/50
# 2322/2322 [==============================] - 2s 682us/step - loss: 0.1446 - matthews_correlation: 0.4165 - val_loss: 0.1009 - val_matthews_correlation: 0.6560
#
# Epoch 00010: val_matthews_correlation improved from 0.29297 to 0.65598, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 2s 690us/step - loss: 0.1209 - matthews_correlation: 0.5256 - val_loss: 0.0861 - val_matthews_correlation: 0.7524
#
# Epoch 00011: val_matthews_correlation improved from 0.65598 to 0.75241, saving model to weights_0.h5
# Epoch 12/50
# 2322/2322 [==============================] - 2s 680us/step - loss: 0.1097 - matthews_correlation: 0.6316 - val_loss: 0.0879 - val_matthews_correlation: 0.7822
#
# Epoch 00012: val_matthews_correlation improved from 0.75241 to 0.78221, saving model to weights_0.h5
# Epoch 13/50
# 2322/2322 [==============================] - 2s 677us/step - loss: 0.1078 - matthews_correlation: 0.6383 - val_loss: 0.0824 - val_matthews_correlation: 0.7836
#
# Epoch 00013: val_matthews_correlation improved from 0.78221 to 0.78361, saving model to weights_0.h5
# Epoch 14/50
# 2322/2322 [==============================] - 2s 683us/step - loss: 0.1131 - matthews_correlation: 0.5609 - val_loss: 0.0836 - val_matthews_correlation: 0.6929
#
# Epoch 00014: val_matthews_correlation did not improve from 0.78361
# Epoch 15/50
# 2322/2322 [==============================] - 2s 684us/step - loss: 0.1109 - matthews_correlation: 0.6273 - val_loss: 0.0881 - val_matthews_correlation: 0.7539
#
# Epoch 00015: val_matthews_correlation did not improve from 0.78361
# Epoch 16/50
# 2322/2322 [==============================] - 2s 686us/step - loss: 0.1026 - matthews_correlation: 0.5849 - val_loss: 0.0772 - val_matthews_correlation: 0.7631
#
# Epoch 00016: val_matthews_correlation did not improve from 0.78361
# Epoch 17/50
# 2322/2322 [==============================] - 2s 683us/step - loss: 0.1018 - matthews_correlation: 0.6576 - val_loss: 0.0750 - val_matthews_correlation: 0.7293
#
# Epoch 00017: val_matthews_correlation did not improve from 0.78361
# Epoch 18/50
# 2322/2322 [==============================] - 2s 684us/step - loss: 0.1013 - matthews_correlation: 0.6473 - val_loss: 0.0823 - val_matthews_correlation: 0.7055
#
# Epoch 00018: val_matthews_correlation did not improve from 0.78361
# Epoch 19/50
# 2322/2322 [==============================] - 2s 682us/step - loss: 0.1069 - matthews_correlation: 0.6275 - val_loss: 0.0749 - val_matthews_correlation: 0.7739
#
# Epoch 00019: val_matthews_correlation did not improve from 0.78361
# Epoch 20/50
# 2322/2322 [==============================] - 2s 681us/step - loss: 0.1138 - matthews_correlation: 0.5537 - val_loss: 0.0835 - val_matthews_correlation: 0.7634
#
# Epoch 00020: val_matthews_correlation did not improve from 0.78361
# Epoch 21/50
# 2322/2322 [==============================] - 2s 677us/step - loss: 0.1046 - matthews_correlation: 0.6645 - val_loss: 0.0799 - val_matthews_correlation: 0.7705
#
# Epoch 00021: val_matthews_correlation did not improve from 0.78361
# Epoch 22/50
# 2322/2322 [==============================] - 2s 677us/step - loss: 0.1038 - matthews_correlation: 0.5815 - val_loss: 0.0794 - val_matthews_correlation: 0.7538
#
# Epoch 00022: val_matthews_correlation did not improve from 0.78361
# Epoch 23/50
# 2322/2322 [==============================] - 2s 678us/step - loss: 0.1062 - matthews_correlation: 0.6265 - val_loss: 0.0809 - val_matthews_correlation: 0.7294
#
# Epoch 00023: val_matthews_correlation did not improve from 0.78361
# Epoch 24/50
# 2322/2322 [==============================] - 2s 678us/step - loss: 0.1031 - matthews_correlation: 0.6547 - val_loss: 0.0739 - val_matthews_correlation: 0.8012
#
# Epoch 00024: val_matthews_correlation improved from 0.78361 to 0.80124, saving model to weights_0.h5
# Epoch 25/50
# 2322/2322 [==============================] - 2s 681us/step - loss: 0.0952 - matthews_correlation: 0.6814 - val_loss: 0.0729 - val_matthews_correlation: 0.7697
#
# Epoch 00025: val_matthews_correlation did not improve from 0.80124
# Epoch 26/50
# 2322/2322 [==============================] - 2s 687us/step - loss: 0.0940 - matthews_correlation: 0.6718 - val_loss: 0.0811 - val_matthews_correlation: 0.7891
#
# Epoch 00026: val_matthews_correlation did not improve from 0.80124
# Epoch 27/50
# 2322/2322 [==============================] - 2s 683us/step - loss: 0.0934 - matthews_correlation: 0.6651 - val_loss: 0.0754 - val_matthews_correlation: 0.7500
#
# Epoch 00027: val_matthews_correlation did not improve from 0.80124
# Epoch 28/50
# 2322/2322 [==============================] - 2s 686us/step - loss: 0.0947 - matthews_correlation: 0.6598 - val_loss: 0.0855 - val_matthews_correlation: 0.7677
#
# Epoch 00028: val_matthews_correlation did not improve from 0.80124
# Epoch 29/50
# 2322/2322 [==============================] - 2s 691us/step - loss: 0.0929 - matthews_correlation: 0.6227 - val_loss: 0.0828 - val_matthews_correlation: 0.7791
#
# Epoch 00029: val_matthews_correlation did not improve from 0.80124
# Epoch 30/50
# 2322/2322 [==============================] - 2s 685us/step - loss: 0.0930 - matthews_correlation: 0.6253 - val_loss: 0.0958 - val_matthews_correlation: 0.5539
#
# Epoch 00030: val_matthews_correlation did not improve from 0.80124
# Epoch 31/50
# 2322/2322 [==============================] - 2s 686us/step - loss: 0.0952 - matthews_correlation: 0.6280 - val_loss: 0.0724 - val_matthews_correlation: 0.8173
#
# Epoch 00031: val_matthews_correlation improved from 0.80124 to 0.81728, saving model to weights_0.h5
# Epoch 32/50
# 2322/2322 [==============================] - 2s 692us/step - loss: 0.0900 - matthews_correlation: 0.7198 - val_loss: 0.0854 - val_matthews_correlation: 0.7809
#
# Epoch 00032: val_matthews_correlation did not improve from 0.81728
# Epoch 33/50
# 2322/2322 [==============================] - 2s 689us/step - loss: 0.0926 - matthews_correlation: 0.6518 - val_loss: 0.0770 - val_matthews_correlation: 0.7795
#
# Epoch 00033: val_matthews_correlation did not improve from 0.81728
# Epoch 34/50
# 2322/2322 [==============================] - 2s 684us/step - loss: 0.0906 - matthews_correlation: 0.6833 - val_loss: 0.0842 - val_matthews_correlation: 0.6661
#
# Epoch 00034: val_matthews_correlation did not improve from 0.81728
# Epoch 35/50
# 2322/2322 [==============================] - 2s 685us/step - loss: 0.0984 - matthews_correlation: 0.5854 - val_loss: 0.0777 - val_matthews_correlation: 0.7857
#
# Epoch 00035: val_matthews_correlation did not improve from 0.81728
# Epoch 36/50
# 2322/2322 [==============================] - 2s 686us/step - loss: 0.0974 - matthews_correlation: 0.6296 - val_loss: 0.0852 - val_matthews_correlation: 0.7499
#
# Epoch 00036: val_matthews_correlation did not improve from 0.81728
# Epoch 37/50
# 2322/2322 [==============================] - 2s 683us/step - loss: 0.0934 - matthews_correlation: 0.6560 - val_loss: 0.0777 - val_matthews_correlation: 0.8130
#
# Epoch 00037: val_matthews_correlation did not improve from 0.81728
# Epoch 38/50
# 2322/2322 [==============================] - 2s 680us/step - loss: 0.0909 - matthews_correlation: 0.6669 - val_loss: 0.0784 - val_matthews_correlation: 0.7535
#
# Epoch 00038: val_matthews_correlation did not improve from 0.81728
# Epoch 39/50
# 2322/2322 [==============================] - 2s 674us/step - loss: 0.0929 - matthews_correlation: 0.6388 - val_loss: 0.0988 - val_matthews_correlation: 0.7009
#
# Epoch 00039: val_matthews_correlation did not improve from 0.81728
# Epoch 40/50
# 2322/2322 [==============================] - 2s 674us/step - loss: 0.0947 - matthews_correlation: 0.6705 - val_loss: 0.0797 - val_matthews_correlation: 0.7833
#
# Epoch 00040: val_matthews_correlation did not improve from 0.81728
# Epoch 41/50
# 2322/2322 [==============================] - 2s 680us/step - loss: 0.0871 - matthews_correlation: 0.7059 - val_loss: 0.0898 - val_matthews_correlation: 0.6302
#
# Epoch 00041: val_matthews_correlation did not improve from 0.81728
# Epoch 42/50
# 2322/2322 [==============================] - 2s 678us/step - loss: 0.0899 - matthews_correlation: 0.6414 - val_loss: 0.0910 - val_matthews_correlation: 0.7765
#
# Epoch 00042: val_matthews_correlation did not improve from 0.81728
# Epoch 43/50
# 2322/2322 [==============================] - 2s 676us/step - loss: 0.0913 - matthews_correlation: 0.6588 - val_loss: 0.0836 - val_matthews_correlation: 0.7637
#
# Epoch 00043: val_matthews_correlation did not improve from 0.81728
# Epoch 44/50
# 2322/2322 [==============================] - 2s 677us/step - loss: 0.0921 - matthews_correlation: 0.6864 - val_loss: 0.0848 - val_matthews_correlation: 0.7834
#
# Epoch 00044: val_matthews_correlation did not improve from 0.81728
# Epoch 45/50
# 2322/2322 [==============================] - 2s 680us/step - loss: 0.0881 - matthews_correlation: 0.6996 - val_loss: 0.0811 - val_matthews_correlation: 0.8030
#
# Epoch 00045: val_matthews_correlation did not improve from 0.81728
# Epoch 46/50
# 2322/2322 [==============================] - 2s 678us/step - loss: 0.0839 - matthews_correlation: 0.6723 - val_loss: 0.0864 - val_matthews_correlation: 0.7130
#
# Epoch 00046: val_matthews_correlation did not improve from 0.81728
# Epoch 47/50
# 2322/2322 [==============================] - 2s 684us/step - loss: 0.0922 - matthews_correlation: 0.7026 - val_loss: 0.0880 - val_matthews_correlation: 0.5815
#
# Epoch 00047: val_matthews_correlation did not improve from 0.81728
# Epoch 48/50
# 2322/2322 [==============================] - 2s 683us/step - loss: 0.0829 - matthews_correlation: 0.7024 - val_loss: 0.0817 - val_matthews_correlation: 0.7833
#
# Epoch 00048: val_matthews_correlation did not improve from 0.81728
# Epoch 49/50
# 2322/2322 [==============================] - 2s 679us/step - loss: 0.0788 - matthews_correlation: 0.7197 - val_loss: 0.0844 - val_matthews_correlation: 0.7541
#
# Epoch 00049: val_matthews_correlation did not improve from 0.81728
# Epoch 50/50
# 2322/2322 [==============================] - 2s 685us/step - loss: 0.0813 - matthews_correlation: 0.7031 - val_loss: 0.0836 - val_matthews_correlation: 0.6432
#
# Epoch 00050: val_matthews_correlation did not improve from 0.81728
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.3993 - matthews_correlation: -0.0036 - val_loss: 0.2545 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.2385 - matthews_correlation: 0.0000e+00 - val_loss: 0.2441 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 2s 681us/step - loss: 0.2119 - matthews_correlation: 0.0032 - val_loss: 0.2100 - val_matthews_correlation: 0.1045
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.10453, saving model to weights_1.h5
# Epoch 4/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.1887 - matthews_correlation: 0.3097 - val_loss: 0.1946 - val_matthews_correlation: 0.1045
#
# Epoch 00004: val_matthews_correlation did not improve from 0.10453
# Epoch 5/50
# 2323/2323 [==============================] - 2s 679us/step - loss: 0.1728 - matthews_correlation: 0.3190 - val_loss: 0.1790 - val_matthews_correlation: 0.0806
#
# Epoch 00005: val_matthews_correlation did not improve from 0.10453
# Epoch 6/50
# 2323/2323 [==============================] - 2s 679us/step - loss: 0.1608 - matthews_correlation: 0.3186 - val_loss: 0.1655 - val_matthews_correlation: 0.0890
#
# Epoch 00006: val_matthews_correlation did not improve from 0.10453
# Epoch 7/50
# 2323/2323 [==============================] - 2s 680us/step - loss: 0.1489 - matthews_correlation: 0.2874 - val_loss: 0.1261 - val_matthews_correlation: 0.4970
#
# Epoch 00007: val_matthews_correlation improved from 0.10453 to 0.49697, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 2s 680us/step - loss: 0.1284 - matthews_correlation: 0.4358 - val_loss: 0.1445 - val_matthews_correlation: 0.4183
#
# Epoch 00008: val_matthews_correlation did not improve from 0.49697
# Epoch 9/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.1287 - matthews_correlation: 0.5257 - val_loss: 0.1514 - val_matthews_correlation: 0.6131
#
# Epoch 00009: val_matthews_correlation improved from 0.49697 to 0.61313, saving model to weights_1.h5
# Epoch 10/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.1263 - matthews_correlation: 0.5293 - val_loss: 0.1222 - val_matthews_correlation: 0.5981
#
# Epoch 00010: val_matthews_correlation did not improve from 0.61313
# Epoch 11/50
# 2323/2323 [==============================] - 2s 693us/step - loss: 0.1217 - matthews_correlation: 0.5407 - val_loss: 0.1132 - val_matthews_correlation: 0.5026
#
# Epoch 00011: val_matthews_correlation did not improve from 0.61313
# Epoch 12/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.1201 - matthews_correlation: 0.5593 - val_loss: 0.1177 - val_matthews_correlation: 0.6667
#
# Epoch 00012: val_matthews_correlation improved from 0.61313 to 0.66673, saving model to weights_1.h5
# Epoch 13/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.1114 - matthews_correlation: 0.5878 - val_loss: 0.1096 - val_matthews_correlation: 0.6658
#
# Epoch 00013: val_matthews_correlation did not improve from 0.66673
# Epoch 14/50
# 2323/2323 [==============================] - 2s 681us/step - loss: 0.1069 - matthews_correlation: 0.6174 - val_loss: 0.1095 - val_matthews_correlation: 0.6086
#
# Epoch 00014: val_matthews_correlation did not improve from 0.66673
# Epoch 15/50
# 2323/2323 [==============================] - 2s 673us/step - loss: 0.1024 - matthews_correlation: 0.6210 - val_loss: 0.1019 - val_matthews_correlation: 0.6812
#
# Epoch 00015: val_matthews_correlation improved from 0.66673 to 0.68121, saving model to weights_1.h5
# Epoch 16/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.0992 - matthews_correlation: 0.6432 - val_loss: 0.1177 - val_matthews_correlation: 0.6352
#
# Epoch 00016: val_matthews_correlation did not improve from 0.68121
# Epoch 17/50
# 2323/2323 [==============================] - 2s 679us/step - loss: 0.1011 - matthews_correlation: 0.6474 - val_loss: 0.0908 - val_matthews_correlation: 0.7717
#
# Epoch 00017: val_matthews_correlation improved from 0.68121 to 0.77167, saving model to weights_1.h5
# Epoch 18/50
# 2323/2323 [==============================] - 2s 681us/step - loss: 0.1033 - matthews_correlation: 0.6637 - val_loss: 0.0988 - val_matthews_correlation: 0.7387
#
# Epoch 00018: val_matthews_correlation did not improve from 0.77167
# Epoch 19/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.1000 - matthews_correlation: 0.6291 - val_loss: 0.0989 - val_matthews_correlation: 0.6750
#
# Epoch 00019: val_matthews_correlation did not improve from 0.77167
# Epoch 20/50
# 2323/2323 [==============================] - 2s 687us/step - loss: 0.0993 - matthews_correlation: 0.6303 - val_loss: 0.1041 - val_matthews_correlation: 0.6490
#
# Epoch 00020: val_matthews_correlation did not improve from 0.77167
# Epoch 21/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.0993 - matthews_correlation: 0.6601 - val_loss: 0.1018 - val_matthews_correlation: 0.7251
#
# Epoch 00021: val_matthews_correlation did not improve from 0.77167
# Epoch 22/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0972 - matthews_correlation: 0.6727 - val_loss: 0.1298 - val_matthews_correlation: 0.6499
#
# Epoch 00022: val_matthews_correlation did not improve from 0.77167
# Epoch 23/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.0974 - matthews_correlation: 0.6536 - val_loss: 0.1215 - val_matthews_correlation: 0.6348
#
# Epoch 00023: val_matthews_correlation did not improve from 0.77167
# Epoch 24/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.0969 - matthews_correlation: 0.6796 - val_loss: 0.1091 - val_matthews_correlation: 0.6688
#
# Epoch 00024: val_matthews_correlation did not improve from 0.77167
# Epoch 25/50
# 2323/2323 [==============================] - 2s 680us/step - loss: 0.0945 - matthews_correlation: 0.6501 - val_loss: 0.0923 - val_matthews_correlation: 0.7449
#
# Epoch 00025: val_matthews_correlation did not improve from 0.77167
# Epoch 26/50
# 2323/2323 [==============================] - 2s 689us/step - loss: 0.0934 - matthews_correlation: 0.6053 - val_loss: 0.1362 - val_matthews_correlation: 0.6809
#
# Epoch 00026: val_matthews_correlation did not improve from 0.77167
# Epoch 27/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.1031 - matthews_correlation: 0.6569 - val_loss: 0.1065 - val_matthews_correlation: 0.6887
#
# Epoch 00027: val_matthews_correlation did not improve from 0.77167
# Epoch 28/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.0952 - matthews_correlation: 0.6548 - val_loss: 0.0989 - val_matthews_correlation: 0.6792
#
# Epoch 00028: val_matthews_correlation did not improve from 0.77167
# Epoch 29/50
# 2323/2323 [==============================] - 2s 681us/step - loss: 0.0900 - matthews_correlation: 0.6654 - val_loss: 0.0961 - val_matthews_correlation: 0.7081
#
# Epoch 00029: val_matthews_correlation did not improve from 0.77167
# Epoch 30/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.0957 - matthews_correlation: 0.6430 - val_loss: 0.1226 - val_matthews_correlation: 0.6556
#
# Epoch 00030: val_matthews_correlation did not improve from 0.77167
# Epoch 31/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.0991 - matthews_correlation: 0.6562 - val_loss: 0.1078 - val_matthews_correlation: 0.6402
#
# Epoch 00031: val_matthews_correlation did not improve from 0.77167
# Epoch 32/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.1005 - matthews_correlation: 0.6057 - val_loss: 0.1248 - val_matthews_correlation: 0.6602
#
# Epoch 00032: val_matthews_correlation did not improve from 0.77167
# Epoch 33/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.0969 - matthews_correlation: 0.6765 - val_loss: 0.1002 - val_matthews_correlation: 0.6791
#
# Epoch 00033: val_matthews_correlation did not improve from 0.77167
# Epoch 34/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.0914 - matthews_correlation: 0.6763 - val_loss: 0.0985 - val_matthews_correlation: 0.6975
#
# Epoch 00034: val_matthews_correlation did not improve from 0.77167
# Epoch 35/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0950 - matthews_correlation: 0.6276 - val_loss: 0.1199 - val_matthews_correlation: 0.6727
#
# Epoch 00035: val_matthews_correlation did not improve from 0.77167
# Epoch 36/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.0939 - matthews_correlation: 0.6512 - val_loss: 0.1030 - val_matthews_correlation: 0.6772
#
# Epoch 00036: val_matthews_correlation did not improve from 0.77167
# Epoch 37/50
# 2323/2323 [==============================] - 2s 689us/step - loss: 0.0893 - matthews_correlation: 0.6791 - val_loss: 0.1037 - val_matthews_correlation: 0.6832
#
# Epoch 00037: val_matthews_correlation did not improve from 0.77167
# Epoch 38/50
# 2323/2323 [==============================] - 2s 687us/step - loss: 0.0849 - matthews_correlation: 0.7156 - val_loss: 0.1096 - val_matthews_correlation: 0.6395
#
# Epoch 00038: val_matthews_correlation did not improve from 0.77167
# Epoch 39/50
# 2323/2323 [==============================] - 2s 687us/step - loss: 0.0841 - matthews_correlation: 0.7005 - val_loss: 0.1046 - val_matthews_correlation: 0.6772
#
# Epoch 00039: val_matthews_correlation did not improve from 0.77167
# Epoch 40/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.0857 - matthews_correlation: 0.6986 - val_loss: 0.1146 - val_matthews_correlation: 0.6593
#
# Epoch 00040: val_matthews_correlation did not improve from 0.77167
# Epoch 41/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0943 - matthews_correlation: 0.7159 - val_loss: 0.1275 - val_matthews_correlation: 0.6432
#
# Epoch 00041: val_matthews_correlation did not improve from 0.77167
# Epoch 42/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.0970 - matthews_correlation: 0.6681 - val_loss: 0.1146 - val_matthews_correlation: 0.6405
#
# Epoch 00042: val_matthews_correlation did not improve from 0.77167
# Epoch 43/50
# 2323/2323 [==============================] - 2s 680us/step - loss: 0.0905 - matthews_correlation: 0.6834 - val_loss: 0.0936 - val_matthews_correlation: 0.7281
#
# Epoch 00043: val_matthews_correlation did not improve from 0.77167
# Epoch 44/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.0887 - matthews_correlation: 0.7084 - val_loss: 0.1009 - val_matthews_correlation: 0.6651
#
# Epoch 00044: val_matthews_correlation did not improve from 0.77167
# Epoch 45/50
# 2323/2323 [==============================] - 2s 681us/step - loss: 0.0929 - matthews_correlation: 0.6799 - val_loss: 0.1004 - val_matthews_correlation: 0.6386
#
# Epoch 00045: val_matthews_correlation did not improve from 0.77167
# Epoch 46/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0874 - matthews_correlation: 0.6942 - val_loss: 0.1163 - val_matthews_correlation: 0.6277
#
# Epoch 00046: val_matthews_correlation did not improve from 0.77167
# Epoch 47/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.0843 - matthews_correlation: 0.7023 - val_loss: 0.1065 - val_matthews_correlation: 0.6351
#
# Epoch 00047: val_matthews_correlation did not improve from 0.77167
# Epoch 48/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.0846 - matthews_correlation: 0.6996 - val_loss: 0.1158 - val_matthews_correlation: 0.5803
#
# Epoch 00048: val_matthews_correlation did not improve from 0.77167
# Epoch 49/50
# 2323/2323 [==============================] - 2s 690us/step - loss: 0.0818 - matthews_correlation: 0.6893 - val_loss: 0.1140 - val_matthews_correlation: 0.6059
#
# Epoch 00049: val_matthews_correlation did not improve from 0.77167
# Epoch 50/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0814 - matthews_correlation: 0.7036 - val_loss: 0.1239 - val_matthews_correlation: 0.6414
#
# Epoch 00050: val_matthews_correlation did not improve from 0.77167
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.3734 - matthews_correlation: 0.0000e+00 - val_loss: 0.2646 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.2389 - matthews_correlation: 0.0000e+00 - val_loss: 0.2230 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.2097 - matthews_correlation: 0.0746 - val_loss: 0.1968 - val_matthews_correlation: 0.1187
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.11874, saving model to weights_2.h5
# Epoch 4/50
# 2323/2323 [==============================] - 2s 679us/step - loss: 0.2014 - matthews_correlation: 0.0981 - val_loss: 0.1928 - val_matthews_correlation: 0.3496
#
# Epoch 00004: val_matthews_correlation improved from 0.11874 to 0.34964, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 2s 678us/step - loss: 0.1809 - matthews_correlation: 0.2476 - val_loss: 0.1635 - val_matthews_correlation: -0.0050
#
# Epoch 00005: val_matthews_correlation did not improve from 0.34964
# Epoch 6/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.1515 - matthews_correlation: 0.0335 - val_loss: 0.1413 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.34964
# Epoch 7/50
# 2323/2323 [==============================] - 2s 678us/step - loss: 0.1265 - matthews_correlation: 0.5161 - val_loss: 0.1501 - val_matthews_correlation: 0.2719
#
# Epoch 00007: val_matthews_correlation did not improve from 0.34964
# Epoch 8/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.1321 - matthews_correlation: 0.5147 - val_loss: 0.1586 - val_matthews_correlation: 0.1733
#
# Epoch 00008: val_matthews_correlation did not improve from 0.34964
# Epoch 9/50
# 2323/2323 [==============================] - 2s 693us/step - loss: 0.1262 - matthews_correlation: 0.5018 - val_loss: 0.1257 - val_matthews_correlation: 0.4701
#
# Epoch 00009: val_matthews_correlation improved from 0.34964 to 0.47012, saving model to weights_2.h5
# Epoch 10/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.1449 - matthews_correlation: 0.3991 - val_loss: 0.1666 - val_matthews_correlation: 0.3200
#
# Epoch 00010: val_matthews_correlation did not improve from 0.47012
# Epoch 11/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.1673 - matthews_correlation: 0.3651 - val_loss: 0.1674 - val_matthews_correlation: 0.3116
#
# Epoch 00011: val_matthews_correlation did not improve from 0.47012
# Epoch 12/50
# 2323/2323 [==============================] - 2s 691us/step - loss: 0.1190 - matthews_correlation: 0.5616 - val_loss: 0.1253 - val_matthews_correlation: 0.4395
#
# Epoch 00012: val_matthews_correlation did not improve from 0.47012
# Epoch 13/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.1038 - matthews_correlation: 0.6917 - val_loss: 0.1240 - val_matthews_correlation: 0.3502
#
# Epoch 00013: val_matthews_correlation did not improve from 0.47012
# Epoch 14/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.1025 - matthews_correlation: 0.6270 - val_loss: 0.1191 - val_matthews_correlation: 0.6345
#
# Epoch 00014: val_matthews_correlation improved from 0.47012 to 0.63449, saving model to weights_2.h5
# Epoch 15/50
# 2323/2323 [==============================] - 2s 694us/step - loss: 0.1114 - matthews_correlation: 0.5630 - val_loss: 0.1264 - val_matthews_correlation: 0.3357
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63449
# Epoch 16/50
# 2323/2323 [==============================] - 2s 691us/step - loss: 0.1013 - matthews_correlation: 0.6238 - val_loss: 0.1180 - val_matthews_correlation: 0.6275
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63449
# Epoch 17/50
# 2323/2323 [==============================] - 2s 690us/step - loss: 0.1022 - matthews_correlation: 0.7103 - val_loss: 0.1199 - val_matthews_correlation: 0.4836
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63449
# Epoch 18/50
# 2323/2323 [==============================] - 2s 696us/step - loss: 0.0960 - matthews_correlation: 0.6924 - val_loss: 0.1192 - val_matthews_correlation: 0.5429
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63449
# Epoch 19/50
# 2323/2323 [==============================] - 2s 691us/step - loss: 0.1003 - matthews_correlation: 0.6642 - val_loss: 0.1292 - val_matthews_correlation: 0.4581
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63449
# Epoch 20/50
# 2323/2323 [==============================] - 2s 692us/step - loss: 0.1010 - matthews_correlation: 0.6175 - val_loss: 0.1184 - val_matthews_correlation: 0.5042
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63449
# Epoch 21/50
# 2323/2323 [==============================] - 2s 695us/step - loss: 0.1075 - matthews_correlation: 0.6776 - val_loss: 0.1174 - val_matthews_correlation: 0.4986
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63449
# Epoch 22/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.0920 - matthews_correlation: 0.6546 - val_loss: 0.1175 - val_matthews_correlation: 0.5899
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63449
# Epoch 23/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.0938 - matthews_correlation: 0.6705 - val_loss: 0.1224 - val_matthews_correlation: 0.5219
#
# Epoch 00023: val_matthews_correlation did not improve from 0.63449
# Epoch 24/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.0959 - matthews_correlation: 0.6912 - val_loss: 0.1211 - val_matthews_correlation: 0.5464
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63449
# Epoch 25/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.0920 - matthews_correlation: 0.6735 - val_loss: 0.1221 - val_matthews_correlation: 0.5802
#
# Epoch 00025: val_matthews_correlation did not improve from 0.63449
# Epoch 26/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.0921 - matthews_correlation: 0.6761 - val_loss: 0.1193 - val_matthews_correlation: 0.5518
#
# Epoch 00026: val_matthews_correlation did not improve from 0.63449
# Epoch 27/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.0899 - matthews_correlation: 0.6866 - val_loss: 0.1195 - val_matthews_correlation: 0.5412
#
# Epoch 00027: val_matthews_correlation did not improve from 0.63449
# Epoch 28/50
# 2323/2323 [==============================] - 2s 689us/step - loss: 0.0911 - matthews_correlation: 0.6854 - val_loss: 0.1237 - val_matthews_correlation: 0.4846
#
# Epoch 00028: val_matthews_correlation did not improve from 0.63449
# Epoch 29/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0919 - matthews_correlation: 0.6894 - val_loss: 0.1213 - val_matthews_correlation: 0.5787
#
# Epoch 00029: val_matthews_correlation did not improve from 0.63449
# Epoch 30/50
# 2323/2323 [==============================] - 2s 686us/step - loss: 0.0978 - matthews_correlation: 0.6769 - val_loss: 0.1228 - val_matthews_correlation: 0.4558
#
# Epoch 00030: val_matthews_correlation did not improve from 0.63449
# Epoch 31/50
# 2323/2323 [==============================] - 2s 692us/step - loss: 0.0935 - matthews_correlation: 0.6631 - val_loss: 0.1166 - val_matthews_correlation: 0.5198
#
# Epoch 00031: val_matthews_correlation did not improve from 0.63449
# Epoch 32/50
# 2323/2323 [==============================] - 2s 690us/step - loss: 0.0884 - matthews_correlation: 0.6723 - val_loss: 0.1382 - val_matthews_correlation: 0.4085
#
# Epoch 00032: val_matthews_correlation did not improve from 0.63449
# Epoch 33/50
# 2323/2323 [==============================] - 2s 693us/step - loss: 0.0924 - matthews_correlation: 0.6903 - val_loss: 0.1248 - val_matthews_correlation: 0.5083
#
# Epoch 00033: val_matthews_correlation did not improve from 0.63449
# Epoch 34/50
# 2323/2323 [==============================] - 2s 685us/step - loss: 0.0872 - matthews_correlation: 0.7340 - val_loss: 0.1191 - val_matthews_correlation: 0.5993
#
# Epoch 00034: val_matthews_correlation did not improve from 0.63449
# Epoch 35/50
# 2323/2323 [==============================] - 2s 693us/step - loss: 0.0988 - matthews_correlation: 0.7233 - val_loss: 0.1201 - val_matthews_correlation: 0.5902
#
# Epoch 00035: val_matthews_correlation did not improve from 0.63449
# Epoch 36/50
# 2323/2323 [==============================] - 2s 689us/step - loss: 0.0864 - matthews_correlation: 0.7156 - val_loss: 0.1189 - val_matthews_correlation: 0.5857
#
# Epoch 00036: val_matthews_correlation did not improve from 0.63449
# Epoch 37/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.0798 - matthews_correlation: 0.7475 - val_loss: 0.1162 - val_matthews_correlation: 0.6103
#
# Epoch 00037: val_matthews_correlation did not improve from 0.63449
# Epoch 38/50
# 2323/2323 [==============================] - 2s 691us/step - loss: 0.0854 - matthews_correlation: 0.6862 - val_loss: 0.1379 - val_matthews_correlation: 0.4556
#
# Epoch 00038: val_matthews_correlation did not improve from 0.63449
# Epoch 39/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.0889 - matthews_correlation: 0.7161 - val_loss: 0.1169 - val_matthews_correlation: 0.6074
#
# Epoch 00039: val_matthews_correlation did not improve from 0.63449
# Epoch 40/50
# 2323/2323 [==============================] - 2s 687us/step - loss: 0.0791 - matthews_correlation: 0.7536 - val_loss: 0.1180 - val_matthews_correlation: 0.5988
#
# Epoch 00040: val_matthews_correlation did not improve from 0.63449
# Epoch 41/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.0846 - matthews_correlation: 0.7185 - val_loss: 0.1176 - val_matthews_correlation: 0.6081
#
# Epoch 00041: val_matthews_correlation did not improve from 0.63449
# Epoch 42/50
# 2323/2323 [==============================] - 2s 691us/step - loss: 0.0797 - matthews_correlation: 0.7487 - val_loss: 0.1102 - val_matthews_correlation: 0.6786
#
# Epoch 00042: val_matthews_correlation improved from 0.63449 to 0.67862, saving model to weights_2.h5
# Epoch 43/50
# 2323/2323 [==============================] - 2s 688us/step - loss: 0.0881 - matthews_correlation: 0.7016 - val_loss: 0.1153 - val_matthews_correlation: 0.6157
#
# Epoch 00043: val_matthews_correlation did not improve from 0.67862
# Epoch 44/50
# 2323/2323 [==============================] - 2s 684us/step - loss: 0.0788 - matthews_correlation: 0.7599 - val_loss: 0.1134 - val_matthews_correlation: 0.5328
#
# Epoch 00044: val_matthews_correlation did not improve from 0.67862
# Epoch 45/50
# 2323/2323 [==============================] - 2s 679us/step - loss: 0.0762 - matthews_correlation: 0.7667 - val_loss: 0.1236 - val_matthews_correlation: 0.6100
#
# Epoch 00045: val_matthews_correlation did not improve from 0.67862
# Epoch 46/50
# 2323/2323 [==============================] - 2s 681us/step - loss: 0.0805 - matthews_correlation: 0.7519 - val_loss: 0.1162 - val_matthews_correlation: 0.6338
#
# Epoch 00046: val_matthews_correlation did not improve from 0.67862
# Epoch 47/50
# 2323/2323 [==============================] - 2s 682us/step - loss: 0.0821 - matthews_correlation: 0.7261 - val_loss: 0.1211 - val_matthews_correlation: 0.6397
#
# Epoch 00047: val_matthews_correlation did not improve from 0.67862
# Epoch 48/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0779 - matthews_correlation: 0.7608 - val_loss: 0.1212 - val_matthews_correlation: 0.6100
#
# Epoch 00048: val_matthews_correlation did not improve from 0.67862
# Epoch 49/50
# 2323/2323 [==============================] - 2s 681us/step - loss: 0.0755 - matthews_correlation: 0.7647 - val_loss: 0.1166 - val_matthews_correlation: 0.6635
#
# Epoch 00049: val_matthews_correlation did not improve from 0.67862
# Epoch 50/50
# 2323/2323 [==============================] - 2s 683us/step - loss: 0.0785 - matthews_correlation: 0.7435 - val_loss: 0.1223 - val_matthews_correlation: 0.5229
#
# Epoch 00050: val_matthews_correlation did not improve from 0.67862
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.3659 - matthews_correlation: -0.0013 - val_loss: 0.2538 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 2s 680us/step - loss: 0.2298 - matthews_correlation: 0.0000e+00 - val_loss: 0.2040 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 2s 682us/step - loss: 0.1863 - matthews_correlation: 0.0000e+00 - val_loss: 0.1606 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 2s 679us/step - loss: 0.1686 - matthews_correlation: 0.0167 - val_loss: 0.1633 - val_matthews_correlation: 0.2741
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.27415, saving model to weights_3.h5
# Epoch 5/50
# 2324/2324 [==============================] - 2s 682us/step - loss: 0.1508 - matthews_correlation: 0.1886 - val_loss: 0.1510 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.27415
# Epoch 6/50
# 2324/2324 [==============================] - 2s 682us/step - loss: 0.1608 - matthews_correlation: 0.1201 - val_loss: 0.1408 - val_matthews_correlation: 0.2686
#
# Epoch 00006: val_matthews_correlation did not improve from 0.27415
# Epoch 7/50
# 2324/2324 [==============================] - 2s 679us/step - loss: 0.1277 - matthews_correlation: 0.4670 - val_loss: 0.1345 - val_matthews_correlation: 0.3889
#
# Epoch 00007: val_matthews_correlation improved from 0.27415 to 0.38893, saving model to weights_3.h5
# Epoch 8/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.1227 - matthews_correlation: 0.4863 - val_loss: 0.1163 - val_matthews_correlation: 0.4924
#
# Epoch 00008: val_matthews_correlation improved from 0.38893 to 0.49237, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 2s 684us/step - loss: 0.1078 - matthews_correlation: 0.6576 - val_loss: 0.1538 - val_matthews_correlation: 0.3850
#
# Epoch 00009: val_matthews_correlation did not improve from 0.49237
# Epoch 10/50
# 2324/2324 [==============================] - 2s 681us/step - loss: 0.1170 - matthews_correlation: 0.5469 - val_loss: 0.1405 - val_matthews_correlation: 0.6250
#
# Epoch 00010: val_matthews_correlation improved from 0.49237 to 0.62501, saving model to weights_3.h5
# Epoch 11/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.1193 - matthews_correlation: 0.5078 - val_loss: 0.1306 - val_matthews_correlation: 0.4562
#
# Epoch 00011: val_matthews_correlation did not improve from 0.62501
# Epoch 12/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.1038 - matthews_correlation: 0.6590 - val_loss: 0.1067 - val_matthews_correlation: 0.5726
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62501
# Epoch 13/50
# 2324/2324 [==============================] - 2s 697us/step - loss: 0.1002 - matthews_correlation: 0.6742 - val_loss: 0.1116 - val_matthews_correlation: 0.5282
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62501
# Epoch 14/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.1068 - matthews_correlation: 0.6309 - val_loss: 0.1109 - val_matthews_correlation: 0.5154
#
# Epoch 00014: val_matthews_correlation did not improve from 0.62501
# Epoch 15/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.1000 - matthews_correlation: 0.6306 - val_loss: 0.1075 - val_matthews_correlation: 0.6469
#
# Epoch 00015: val_matthews_correlation improved from 0.62501 to 0.64693, saving model to weights_3.h5
# Epoch 16/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0955 - matthews_correlation: 0.6700 - val_loss: 0.1110 - val_matthews_correlation: 0.6491
#
# Epoch 00016: val_matthews_correlation improved from 0.64693 to 0.64911, saving model to weights_3.h5
# Epoch 17/50
# 2324/2324 [==============================] - 2s 690us/step - loss: 0.0958 - matthews_correlation: 0.6816 - val_loss: 0.1016 - val_matthews_correlation: 0.6469
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64911
# Epoch 18/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0970 - matthews_correlation: 0.6683 - val_loss: 0.1123 - val_matthews_correlation: 0.5119
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64911
# Epoch 19/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.0988 - matthews_correlation: 0.6894 - val_loss: 0.1070 - val_matthews_correlation: 0.5381
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64911
# Epoch 20/50
# 2324/2324 [==============================] - 2s 690us/step - loss: 0.0961 - matthews_correlation: 0.6470 - val_loss: 0.1039 - val_matthews_correlation: 0.6124
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64911
# Epoch 21/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.0926 - matthews_correlation: 0.7050 - val_loss: 0.1134 - val_matthews_correlation: 0.5296
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64911
# Epoch 22/50
# 2324/2324 [==============================] - 2s 684us/step - loss: 0.0989 - matthews_correlation: 0.6175 - val_loss: 0.1160 - val_matthews_correlation: 0.6386
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64911
# Epoch 23/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.0966 - matthews_correlation: 0.6927 - val_loss: 0.0999 - val_matthews_correlation: 0.6286
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64911
# Epoch 24/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0953 - matthews_correlation: 0.6664 - val_loss: 0.1015 - val_matthews_correlation: 0.6431
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64911
# Epoch 25/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0925 - matthews_correlation: 0.7368 - val_loss: 0.1095 - val_matthews_correlation: 0.5116
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64911
# Epoch 26/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0999 - matthews_correlation: 0.6686 - val_loss: 0.1043 - val_matthews_correlation: 0.5701
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64911
# Epoch 27/50
# 2324/2324 [==============================] - 2s 692us/step - loss: 0.0947 - matthews_correlation: 0.7140 - val_loss: 0.1007 - val_matthews_correlation: 0.6315
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64911
# Epoch 28/50
# 2324/2324 [==============================] - 2s 683us/step - loss: 0.0975 - matthews_correlation: 0.6879 - val_loss: 0.0999 - val_matthews_correlation: 0.5483
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64911
# Epoch 29/50
# 2324/2324 [==============================] - 2s 689us/step - loss: 0.0984 - matthews_correlation: 0.6517 - val_loss: 0.1134 - val_matthews_correlation: 0.5116
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64911
# Epoch 30/50
# 2324/2324 [==============================] - 2s 691us/step - loss: 0.0964 - matthews_correlation: 0.6739 - val_loss: 0.1024 - val_matthews_correlation: 0.5250
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64911
# Epoch 31/50
# 2324/2324 [==============================] - 2s 691us/step - loss: 0.0904 - matthews_correlation: 0.6827 - val_loss: 0.1012 - val_matthews_correlation: 0.6798
#
# Epoch 00031: val_matthews_correlation improved from 0.64911 to 0.67985, saving model to weights_3.h5
# Epoch 32/50
# 2324/2324 [==============================] - 2s 689us/step - loss: 0.0905 - matthews_correlation: 0.7222 - val_loss: 0.0974 - val_matthews_correlation: 0.7138
#
# Epoch 00032: val_matthews_correlation improved from 0.67985 to 0.71380, saving model to weights_3.h5
# Epoch 33/50
# 2324/2324 [==============================] - 2s 689us/step - loss: 0.1138 - matthews_correlation: 0.6315 - val_loss: 0.0996 - val_matthews_correlation: 0.5891
#
# Epoch 00033: val_matthews_correlation did not improve from 0.71380
# Epoch 34/50
# 2324/2324 [==============================] - 2s 684us/step - loss: 0.0888 - matthews_correlation: 0.7585 - val_loss: 0.0993 - val_matthews_correlation: 0.6825
#
# Epoch 00034: val_matthews_correlation did not improve from 0.71380
# Epoch 35/50
# 2324/2324 [==============================] - 2s 691us/step - loss: 0.0931 - matthews_correlation: 0.7190 - val_loss: 0.1113 - val_matthews_correlation: 0.5420
#
# Epoch 00035: val_matthews_correlation did not improve from 0.71380
# Epoch 36/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.0888 - matthews_correlation: 0.7240 - val_loss: 0.0979 - val_matthews_correlation: 0.7052
#
# Epoch 00036: val_matthews_correlation did not improve from 0.71380
# Epoch 37/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.0876 - matthews_correlation: 0.7281 - val_loss: 0.1018 - val_matthews_correlation: 0.6456
#
# Epoch 00037: val_matthews_correlation did not improve from 0.71380
# Epoch 38/50
# 2324/2324 [==============================] - 2s 691us/step - loss: 0.0872 - matthews_correlation: 0.6900 - val_loss: 0.0961 - val_matthews_correlation: 0.6849
#
# Epoch 00038: val_matthews_correlation did not improve from 0.71380
# Epoch 39/50
# 2324/2324 [==============================] - 2s 689us/step - loss: 0.0878 - matthews_correlation: 0.7381 - val_loss: 0.1022 - val_matthews_correlation: 0.5267
#
# Epoch 00039: val_matthews_correlation did not improve from 0.71380
# Epoch 40/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.0841 - matthews_correlation: 0.7253 - val_loss: 0.0958 - val_matthews_correlation: 0.6596
#
# Epoch 00040: val_matthews_correlation did not improve from 0.71380
# Epoch 41/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.0958 - matthews_correlation: 0.7152 - val_loss: 0.1012 - val_matthews_correlation: 0.6504
#
# Epoch 00041: val_matthews_correlation did not improve from 0.71380
# Epoch 42/50
# 2324/2324 [==============================] - 2s 693us/step - loss: 0.0848 - matthews_correlation: 0.7385 - val_loss: 0.0960 - val_matthews_correlation: 0.6849
#
# Epoch 00042: val_matthews_correlation did not improve from 0.71380
# Epoch 43/50
# 2324/2324 [==============================] - 2s 693us/step - loss: 0.0834 - matthews_correlation: 0.7478 - val_loss: 0.1006 - val_matthews_correlation: 0.5193
#
# Epoch 00043: val_matthews_correlation did not improve from 0.71380
# Epoch 44/50
# 2324/2324 [==============================] - 2s 698us/step - loss: 0.0829 - matthews_correlation: 0.7735 - val_loss: 0.1007 - val_matthews_correlation: 0.5769
#
# Epoch 00044: val_matthews_correlation did not improve from 0.71380
# Epoch 45/50
# 2324/2324 [==============================] - 2s 689us/step - loss: 0.0819 - matthews_correlation: 0.7483 - val_loss: 0.1011 - val_matthews_correlation: 0.5316
#
# Epoch 00045: val_matthews_correlation did not improve from 0.71380
# Epoch 46/50
# 2324/2324 [==============================] - 2s 692us/step - loss: 0.0806 - matthews_correlation: 0.7511 - val_loss: 0.0981 - val_matthews_correlation: 0.5867
#
# Epoch 00046: val_matthews_correlation did not improve from 0.71380
# Epoch 47/50
# 2324/2324 [==============================] - 2s 693us/step - loss: 0.0872 - matthews_correlation: 0.7095 - val_loss: 0.1066 - val_matthews_correlation: 0.6332
#
# Epoch 00047: val_matthews_correlation did not improve from 0.71380
# Epoch 48/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.0881 - matthews_correlation: 0.6859 - val_loss: 0.0951 - val_matthews_correlation: 0.6056
#
# Epoch 00048: val_matthews_correlation did not improve from 0.71380
# Epoch 49/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.0804 - matthews_correlation: 0.7527 - val_loss: 0.1054 - val_matthews_correlation: 0.6644
#
# Epoch 00049: val_matthews_correlation did not improve from 0.71380
# Epoch 50/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.0836 - matthews_correlation: 0.7535 - val_loss: 0.1083 - val_matthews_correlation: 0.7303
#
# Epoch 00050: val_matthews_correlation improved from 0.71380 to 0.73029, saving model to weights_3.h5
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.3600 - matthews_correlation: -0.0025 - val_loss: 0.2512 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 2s 694us/step - loss: 0.2353 - matthews_correlation: 0.0000e+00 - val_loss: 0.1983 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 2s 694us/step - loss: 0.2051 - matthews_correlation: 0.0599 - val_loss: 0.1734 - val_matthews_correlation: 0.3249
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.32486, saving model to weights_4.h5
# Epoch 4/50
# 2324/2324 [==============================] - 2s 680us/step - loss: 0.1759 - matthews_correlation: 0.0632 - val_loss: 0.1647 - val_matthews_correlation: 0.4175
#
# Epoch 00004: val_matthews_correlation improved from 0.32486 to 0.41752, saving model to weights_4.h5
# Epoch 5/50
# 2324/2324 [==============================] - 2s 681us/step - loss: 0.1501 - matthews_correlation: 0.1497 - val_loss: 0.1559 - val_matthews_correlation: 0.5295
#
# Epoch 00005: val_matthews_correlation improved from 0.41752 to 0.52950, saving model to weights_4.h5
# Epoch 6/50
# 2324/2324 [==============================] - 2s 682us/step - loss: 0.1377 - matthews_correlation: 0.3533 - val_loss: 0.2504 - val_matthews_correlation: 0.4626
#
# Epoch 00006: val_matthews_correlation did not improve from 0.52950
# Epoch 7/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.1458 - matthews_correlation: 0.3866 - val_loss: 0.1396 - val_matthews_correlation: 0.5155
#
# Epoch 00007: val_matthews_correlation did not improve from 0.52950
# Epoch 8/50
# 2324/2324 [==============================] - 2s 678us/step - loss: 0.1269 - matthews_correlation: 0.4550 - val_loss: 0.1267 - val_matthews_correlation: 0.6240
#
# Epoch 00008: val_matthews_correlation improved from 0.52950 to 0.62399, saving model to weights_4.h5
# Epoch 9/50
# 2324/2324 [==============================] - 2s 681us/step - loss: 0.1132 - matthews_correlation: 0.5848 - val_loss: 0.1210 - val_matthews_correlation: 0.3831
#
# Epoch 00009: val_matthews_correlation did not improve from 0.62399
# Epoch 10/50
# 2324/2324 [==============================] - 2s 678us/step - loss: 0.1049 - matthews_correlation: 0.6438 - val_loss: 0.1259 - val_matthews_correlation: 0.4326
#
# Epoch 00010: val_matthews_correlation did not improve from 0.62399
# Epoch 11/50
# 2324/2324 [==============================] - 2s 681us/step - loss: 0.1030 - matthews_correlation: 0.6151 - val_loss: 0.1287 - val_matthews_correlation: 0.6278
#
# Epoch 00011: val_matthews_correlation improved from 0.62399 to 0.62777, saving model to weights_4.h5
# Epoch 12/50
# 2324/2324 [==============================] - 2s 683us/step - loss: 0.1013 - matthews_correlation: 0.6378 - val_loss: 0.1144 - val_matthews_correlation: 0.5908
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62777
# Epoch 13/50
# 2324/2324 [==============================] - 2s 680us/step - loss: 0.0966 - matthews_correlation: 0.6520 - val_loss: 0.1134 - val_matthews_correlation: 0.6248
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62777
# Epoch 14/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0964 - matthews_correlation: 0.7148 - val_loss: 0.1160 - val_matthews_correlation: 0.5366
#
# Epoch 00014: val_matthews_correlation did not improve from 0.62777
# Epoch 15/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0988 - matthews_correlation: 0.6803 - val_loss: 0.1143 - val_matthews_correlation: 0.5509
#
# Epoch 00015: val_matthews_correlation did not improve from 0.62777
# Epoch 16/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.1011 - matthews_correlation: 0.6307 - val_loss: 0.1084 - val_matthews_correlation: 0.6488
#
# Epoch 00016: val_matthews_correlation improved from 0.62777 to 0.64882, saving model to weights_4.h5
# Epoch 17/50
# 2324/2324 [==============================] - 2s 684us/step - loss: 0.0937 - matthews_correlation: 0.6864 - val_loss: 0.1165 - val_matthews_correlation: 0.6135
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64882
# Epoch 18/50
# 2324/2324 [==============================] - 2s 689us/step - loss: 0.0942 - matthews_correlation: 0.6749 - val_loss: 0.1174 - val_matthews_correlation: 0.6337
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64882
# Epoch 19/50
# 2324/2324 [==============================] - 2s 690us/step - loss: 0.0989 - matthews_correlation: 0.6385 - val_loss: 0.1156 - val_matthews_correlation: 0.5723
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64882
# Epoch 20/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.0963 - matthews_correlation: 0.6462 - val_loss: 0.1142 - val_matthews_correlation: 0.5892
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64882
# Epoch 21/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.0950 - matthews_correlation: 0.6907 - val_loss: 0.1181 - val_matthews_correlation: 0.6294
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64882
# Epoch 22/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.0983 - matthews_correlation: 0.6276 - val_loss: 0.1102 - val_matthews_correlation: 0.6248
#
# Epoch 00022: val_matthews_correlation did not improve from 0.64882
# Epoch 23/50
# 2324/2324 [==============================] - 2s 684us/step - loss: 0.0956 - matthews_correlation: 0.6661 - val_loss: 0.1188 - val_matthews_correlation: 0.4257
#
# Epoch 00023: val_matthews_correlation did not improve from 0.64882
# Epoch 24/50
# 2324/2324 [==============================] - 2s 683us/step - loss: 0.0963 - matthews_correlation: 0.6564 - val_loss: 0.1089 - val_matthews_correlation: 0.6227
#
# Epoch 00024: val_matthews_correlation did not improve from 0.64882
# Epoch 25/50
# 2324/2324 [==============================] - 2s 691us/step - loss: 0.0904 - matthews_correlation: 0.7198 - val_loss: 0.1126 - val_matthews_correlation: 0.5835
#
# Epoch 00025: val_matthews_correlation did not improve from 0.64882
# Epoch 26/50
# 2324/2324 [==============================] - 2s 694us/step - loss: 0.0977 - matthews_correlation: 0.6809 - val_loss: 0.1128 - val_matthews_correlation: 0.6130
#
# Epoch 00026: val_matthews_correlation did not improve from 0.64882
# Epoch 27/50
# 2324/2324 [==============================] - 2s 695us/step - loss: 0.0941 - matthews_correlation: 0.6464 - val_loss: 0.1166 - val_matthews_correlation: 0.6093
#
# Epoch 00027: val_matthews_correlation did not improve from 0.64882
# Epoch 28/50
# 2324/2324 [==============================] - 2s 692us/step - loss: 0.0903 - matthews_correlation: 0.6977 - val_loss: 0.1126 - val_matthews_correlation: 0.6253
#
# Epoch 00028: val_matthews_correlation did not improve from 0.64882
# Epoch 29/50
# 2324/2324 [==============================] - 2s 693us/step - loss: 0.0923 - matthews_correlation: 0.7018 - val_loss: 0.1068 - val_matthews_correlation: 0.6053
#
# Epoch 00029: val_matthews_correlation did not improve from 0.64882
# Epoch 30/50
# 2324/2324 [==============================] - 2s 693us/step - loss: 0.0961 - matthews_correlation: 0.6833 - val_loss: 0.1119 - val_matthews_correlation: 0.5467
#
# Epoch 00030: val_matthews_correlation did not improve from 0.64882
# Epoch 31/50
# 2324/2324 [==============================] - 2s 692us/step - loss: 0.0936 - matthews_correlation: 0.7067 - val_loss: 0.1089 - val_matthews_correlation: 0.6258
#
# Epoch 00031: val_matthews_correlation did not improve from 0.64882
# Epoch 32/50
# 2324/2324 [==============================] - 2s 698us/step - loss: 0.0890 - matthews_correlation: 0.7036 - val_loss: 0.1156 - val_matthews_correlation: 0.5723
#
# Epoch 00032: val_matthews_correlation did not improve from 0.64882
# Epoch 33/50
# 2324/2324 [==============================] - 2s 690us/step - loss: 0.0881 - matthews_correlation: 0.7148 - val_loss: 0.1235 - val_matthews_correlation: 0.4230
#
# Epoch 00033: val_matthews_correlation did not improve from 0.64882
# Epoch 34/50
# 2324/2324 [==============================] - 2s 693us/step - loss: 0.0938 - matthews_correlation: 0.6395 - val_loss: 0.1054 - val_matthews_correlation: 0.6192
#
# Epoch 00034: val_matthews_correlation did not improve from 0.64882
# Epoch 35/50
# 2324/2324 [==============================] - 2s 694us/step - loss: 0.1006 - matthews_correlation: 0.6857 - val_loss: 0.1202 - val_matthews_correlation: 0.5554
#
# Epoch 00035: val_matthews_correlation did not improve from 0.64882
# Epoch 36/50
# 2324/2324 [==============================] - 2s 690us/step - loss: 0.0974 - matthews_correlation: 0.6723 - val_loss: 0.1074 - val_matthews_correlation: 0.6205
#
# Epoch 00036: val_matthews_correlation did not improve from 0.64882
# Epoch 37/50
# 2324/2324 [==============================] - 2s 696us/step - loss: 0.0896 - matthews_correlation: 0.6804 - val_loss: 0.1080 - val_matthews_correlation: 0.5889
#
# Epoch 00037: val_matthews_correlation did not improve from 0.64882
# Epoch 38/50
# 2324/2324 [==============================] - 2s 688us/step - loss: 0.0860 - matthews_correlation: 0.7334 - val_loss: 0.1033 - val_matthews_correlation: 0.6173
#
# Epoch 00038: val_matthews_correlation did not improve from 0.64882
# Epoch 39/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0834 - matthews_correlation: 0.7121 - val_loss: 0.1128 - val_matthews_correlation: 0.6138
#
# Epoch 00039: val_matthews_correlation did not improve from 0.64882
# Epoch 40/50
# 2324/2324 [==============================] - 2s 689us/step - loss: 0.0858 - matthews_correlation: 0.7038 - val_loss: 0.1022 - val_matthews_correlation: 0.6328
#
# Epoch 00040: val_matthews_correlation did not improve from 0.64882
# Epoch 41/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.0835 - matthews_correlation: 0.6967 - val_loss: 0.1082 - val_matthews_correlation: 0.6569
#
# Epoch 00041: val_matthews_correlation improved from 0.64882 to 0.65694, saving model to weights_4.h5
# Epoch 42/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0838 - matthews_correlation: 0.6954 - val_loss: 0.1094 - val_matthews_correlation: 0.6245
#
# Epoch 00042: val_matthews_correlation did not improve from 0.65694
# Epoch 43/50
# 2324/2324 [==============================] - 2s 687us/step - loss: 0.0877 - matthews_correlation: 0.6951 - val_loss: 0.1227 - val_matthews_correlation: 0.5871
#
# Epoch 00043: val_matthews_correlation did not improve from 0.65694
# Epoch 44/50
# 2324/2324 [==============================] - 2s 684us/step - loss: 0.0849 - matthews_correlation: 0.7376 - val_loss: 0.1084 - val_matthews_correlation: 0.5724
#
# Epoch 00044: val_matthews_correlation did not improve from 0.65694
# Epoch 45/50
# 2324/2324 [==============================] - 2s 685us/step - loss: 0.0801 - matthews_correlation: 0.6897 - val_loss: 0.1070 - val_matthews_correlation: 0.6341
#
# Epoch 00045: val_matthews_correlation did not improve from 0.65694
# Epoch 46/50
# 2324/2324 [==============================] - 2s 681us/step - loss: 0.0791 - matthews_correlation: 0.7509 - val_loss: 0.1109 - val_matthews_correlation: 0.6177
#
# Epoch 00046: val_matthews_correlation did not improve from 0.65694
# Epoch 47/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.0799 - matthews_correlation: 0.7245 - val_loss: 0.1122 - val_matthews_correlation: 0.5177
#
# Epoch 00047: val_matthews_correlation did not improve from 0.65694
# Epoch 48/50
# 2324/2324 [==============================] - 2s 681us/step - loss: 0.0827 - matthews_correlation: 0.7427 - val_loss: 0.1204 - val_matthews_correlation: 0.4419
#
# Epoch 00048: val_matthews_correlation did not improve from 0.65694
# Epoch 49/50
# 2324/2324 [==============================] - 2s 686us/step - loss: 0.0823 - matthews_correlation: 0.7132 - val_loss: 0.1096 - val_matthews_correlation: 0.6178
#
# Epoch 00049: val_matthews_correlation did not improve from 0.65694
# Epoch 50/50
# 2324/2324 [==============================] - 2s 681us/step - loss: 0.0860 - matthews_correlation: 0.6655 - val_loss: 0.1077 - val_matthews_correlation: 0.6550
#
# Epoch 00050: val_matthews_correlation did not improve from 0.65694
# ((2904,), (2904,))

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
optimal_values = utils.threshold_search(y_val, preds_val)
best_threshold = optimal_values['threshold']
best_score = optimal_values['matthews_correlation']
# Out:
# 100%|██████████| 100/100 [00:43<00:00,  1.36it/s]

# %%
print("Optimal Threshold : " + str(best_threshold))
print("Best Matthews Correlation : " + str(best_score))
# Out:
# Optimal Threshold : 0.48
# Best Matthews Correlation : 0.7343764

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../data/metadata_test.csv')
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 20.8 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../data/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [02:59<00:00, 11.35it/s]
# 100%|██████████| 2033/2033 [03:00<00:00, 11.18it/s]
# 100%|██████████| 2033/2033 [03:01<00:00, 11.12it/s]
# 100%|██████████| 2033/2033 [02:59<00:00, 11.29it/s]
# 100%|██████████| 2033/2033 [02:57<00:00, 11.38it/s]
# 100%|██████████| 2033/2033 [03:01<00:00, 11.19it/s]
# 100%|██████████| 2033/2033 [02:57<00:00, 11.43it/s]
# 100%|██████████| 2033/2033 [02:58<00:00, 11.53it/s]
# 100%|██████████| 2033/2033 [03:02<00:00, 11.14it/s]
# 100%|██████████| 2033/2033 [03:02<00:00, 11.20it/s]
# 100%|██████████| 7/7 [00:00<00:00,  9.55it/s]
# CPU times: user 31min 44s, sys: 43.8 s, total: 32min 28s
# Wall time: 32min 23s

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
signals = X_test_input.reshape((len(X_test_input), X_test_input.shape[1]*X_test_input.shape[2]))
features_test = []

for signal in signals:
    features_test.append(entropy_and_fractal_dim(signal))

# %%
features_test = np.array(features_test).reshape((len(features_test), 7))
features_test = scaler.transform(features_test)
np.save("features_test.npy",features_test)

# %%
submission = pd.read_csv('../data/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict([X_test_input, features_test], batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 1s 207us/step
# 6779/6779 [==============================] - 1s 174us/step
# 6779/6779 [==============================] - 1s 191us/step
# 6779/6779 [==============================] - 1s 192us/step
# 6779/6779 [==============================] - 1s 192us/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0
