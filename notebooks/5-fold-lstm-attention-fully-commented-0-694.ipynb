# %% [markdown]
# ### Meeting a Sayed Athar's request, I'm using the Kernel altered by Khoi Nguyen to explain how the whole code works.
# ### If any part is not clear, please comment.
# ### Please upvote if it was helpful.

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from vsb_signal_dataset import VsbSignalDataset
# Out:
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../data/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
# This is one of the most important peace of code of this Kernel
# Any power line contain 3 phases of 800000 measurements, or 2.4 millions data 
# It would be praticaly impossible to build a NN with an input of that size
# The ideia here is to reduce it each phase to a matrix of <n_dim> bins by n features
# Each bean is a set of 5000 measurements (800000 / 160), so the features are extracted from this 5000 chunk data.
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        # now, we just add all the features to new_ts and convert it to np.array
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):
    # load a piece of data from file
    praq_train = pq.read_pandas('../data/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
    # using tdqm to evaluate processing time
    # takes each index from df_train and iteract it from start to end
    # it is divided by 3 because for each id_measurement there are 3 id_signal, and the start/end parameters are id_signal
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [06:21<00:00,  3.84it/s]
# 100%|██████████| 1452/1452 [06:02<00:00,  4.07it/s]

# %%
# The X shape here is very important. It is also important undertand a little how a LSTM works
# X.shape[0] is the number of id_measuremts contained in train data
# X.shape[1] is the number of chunks resultant of the transformation, each of this date enters in the LSTM serialized
# This way the LSTM can understand the position of a data relative with other and activate a signal that needs
# a serie of inputs in a specifc order.
# X.shape[3] is the number of features multiplied by the number of phases (3)
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(CuDNNLSTM(128, return_sequences=True))(inp)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64, activation="relu")(x)
    # A binnary classification as this must finish with shape (1,)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    # Pay attention in the addition of matthews_correlation metric in the compilation, it is a success factor key
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 6s 3ms/step - loss: 0.3407 - matthews_correlation: -0.0039 - val_loss: 0.2329 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 1s 519us/step - loss: 0.2252 - matthews_correlation: 0.0000e+00 - val_loss: 0.2235 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 1s 521us/step - loss: 0.2167 - matthews_correlation: 0.0000e+00 - val_loss: 0.2105 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 1s 514us/step - loss: 0.1903 - matthews_correlation: 0.0000e+00 - val_loss: 0.1824 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2322/2322 [==============================] - 1s 527us/step - loss: 0.1771 - matthews_correlation: 0.0656 - val_loss: 0.1663 - val_matthews_correlation: 0.2140
#
# Epoch 00005: val_matthews_correlation improved from 0.00000 to 0.21403, saving model to weights_0.h5
# Epoch 6/50
# 2322/2322 [==============================] - 1s 526us/step - loss: 0.1572 - matthews_correlation: 0.2423 - val_loss: 0.1814 - val_matthews_correlation: 0.2157
#
# Epoch 00006: val_matthews_correlation improved from 0.21403 to 0.21575, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 1s 523us/step - loss: 0.1605 - matthews_correlation: 0.2584 - val_loss: 0.1326 - val_matthews_correlation: 0.1923
#
# Epoch 00007: val_matthews_correlation did not improve from 0.21575
# Epoch 8/50
# 2322/2322 [==============================] - 1s 524us/step - loss: 0.1403 - matthews_correlation: 0.4076 - val_loss: 0.1123 - val_matthews_correlation: 0.5799
#
# Epoch 00008: val_matthews_correlation improved from 0.21575 to 0.57987, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 1s 522us/step - loss: 0.1406 - matthews_correlation: 0.3850 - val_loss: 0.1057 - val_matthews_correlation: 0.4159
#
# Epoch 00009: val_matthews_correlation did not improve from 0.57987
# Epoch 10/50
# 2322/2322 [==============================] - 1s 541us/step - loss: 0.1255 - matthews_correlation: 0.5383 - val_loss: 0.1005 - val_matthews_correlation: 0.7011
#
# Epoch 00010: val_matthews_correlation improved from 0.57987 to 0.70115, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 1s 523us/step - loss: 0.1214 - matthews_correlation: 0.5533 - val_loss: 0.0982 - val_matthews_correlation: 0.6565
#
# Epoch 00011: val_matthews_correlation did not improve from 0.70115
# Epoch 12/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.1159 - matthews_correlation: 0.5947 - val_loss: 0.0982 - val_matthews_correlation: 0.7269
#
# Epoch 00012: val_matthews_correlation improved from 0.70115 to 0.72686, saving model to weights_0.h5
# Epoch 13/50
# 2322/2322 [==============================] - 1s 540us/step - loss: 0.1116 - matthews_correlation: 0.6623 - val_loss: 0.1168 - val_matthews_correlation: 0.5539
#
# Epoch 00013: val_matthews_correlation did not improve from 0.72686
# Epoch 14/50
# 2322/2322 [==============================] - 1s 531us/step - loss: 0.1240 - matthews_correlation: 0.6073 - val_loss: 0.1122 - val_matthews_correlation: 0.7526
#
# Epoch 00014: val_matthews_correlation improved from 0.72686 to 0.75265, saving model to weights_0.h5
# Epoch 15/50
# 2322/2322 [==============================] - 1s 527us/step - loss: 0.1174 - matthews_correlation: 0.6101 - val_loss: 0.0884 - val_matthews_correlation: 0.6996
#
# Epoch 00015: val_matthews_correlation did not improve from 0.75265
# Epoch 16/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.1096 - matthews_correlation: 0.6044 - val_loss: 0.0853 - val_matthews_correlation: 0.6708
#
# Epoch 00016: val_matthews_correlation did not improve from 0.75265
# Epoch 17/50
# 2322/2322 [==============================] - 1s 520us/step - loss: 0.1071 - matthews_correlation: 0.6298 - val_loss: 0.0859 - val_matthews_correlation: 0.8039
#
# Epoch 00017: val_matthews_correlation improved from 0.75265 to 0.80388, saving model to weights_0.h5
# Epoch 18/50
# 2322/2322 [==============================] - 1s 511us/step - loss: 0.1046 - matthews_correlation: 0.6791 - val_loss: 0.0924 - val_matthews_correlation: 0.6095
#
# Epoch 00018: val_matthews_correlation did not improve from 0.80388
# Epoch 19/50
# 2322/2322 [==============================] - 1s 517us/step - loss: 0.1088 - matthews_correlation: 0.6363 - val_loss: 0.0861 - val_matthews_correlation: 0.6971
#
# Epoch 00019: val_matthews_correlation did not improve from 0.80388
# Epoch 20/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.1029 - matthews_correlation: 0.6553 - val_loss: 0.1069 - val_matthews_correlation: 0.6995
#
# Epoch 00020: val_matthews_correlation did not improve from 0.80388
# Epoch 21/50
# 2322/2322 [==============================] - 1s 504us/step - loss: 0.1116 - matthews_correlation: 0.6067 - val_loss: 0.0959 - val_matthews_correlation: 0.5535
#
# Epoch 00021: val_matthews_correlation did not improve from 0.80388
# Epoch 22/50
# 2322/2322 [==============================] - 1s 525us/step - loss: 0.1031 - matthews_correlation: 0.6112 - val_loss: 0.0951 - val_matthews_correlation: 0.7360
#
# Epoch 00022: val_matthews_correlation did not improve from 0.80388
# Epoch 23/50
# 2322/2322 [==============================] - 1s 534us/step - loss: 0.1060 - matthews_correlation: 0.6243 - val_loss: 0.0817 - val_matthews_correlation: 0.7260
#
# Epoch 00023: val_matthews_correlation did not improve from 0.80388
# Epoch 24/50
# 2322/2322 [==============================] - 1s 531us/step - loss: 0.0999 - matthews_correlation: 0.6781 - val_loss: 0.0809 - val_matthews_correlation: 0.7618
#
# Epoch 00024: val_matthews_correlation did not improve from 0.80388
# Epoch 25/50
# 2322/2322 [==============================] - 1s 511us/step - loss: 0.0991 - matthews_correlation: 0.6758 - val_loss: 0.0829 - val_matthews_correlation: 0.6448
#
# Epoch 00025: val_matthews_correlation did not improve from 0.80388
# Epoch 26/50
# 2322/2322 [==============================] - 1s 490us/step - loss: 0.0989 - matthews_correlation: 0.6396 - val_loss: 0.0774 - val_matthews_correlation: 0.7988
#
# Epoch 00026: val_matthews_correlation did not improve from 0.80388
# Epoch 27/50
# 2322/2322 [==============================] - 1s 531us/step - loss: 0.1010 - matthews_correlation: 0.7174 - val_loss: 0.0813 - val_matthews_correlation: 0.6971
#
# Epoch 00027: val_matthews_correlation did not improve from 0.80388
# Epoch 28/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.0977 - matthews_correlation: 0.6922 - val_loss: 0.0856 - val_matthews_correlation: 0.6117
#
# Epoch 00028: val_matthews_correlation did not improve from 0.80388
# Epoch 29/50
# 2322/2322 [==============================] - 1s 492us/step - loss: 0.0944 - matthews_correlation: 0.6559 - val_loss: 0.0793 - val_matthews_correlation: 0.7714
#
# Epoch 00029: val_matthews_correlation did not improve from 0.80388
# Epoch 30/50
# 2322/2322 [==============================] - 1s 472us/step - loss: 0.0924 - matthews_correlation: 0.7175 - val_loss: 0.0727 - val_matthews_correlation: 0.8093
#
# Epoch 00030: val_matthews_correlation improved from 0.80388 to 0.80929, saving model to weights_0.h5
# Epoch 31/50
# 2322/2322 [==============================] - 1s 534us/step - loss: 0.0954 - matthews_correlation: 0.6817 - val_loss: 0.0788 - val_matthews_correlation: 0.7157
#
# Epoch 00031: val_matthews_correlation did not improve from 0.80929
# Epoch 32/50
# 2322/2322 [==============================] - 1s 502us/step - loss: 0.1079 - matthews_correlation: 0.6369 - val_loss: 0.0909 - val_matthews_correlation: 0.5002
#
# Epoch 00032: val_matthews_correlation did not improve from 0.80929
# Epoch 33/50
# 2322/2322 [==============================] - 1s 498us/step - loss: 0.1018 - matthews_correlation: 0.6170 - val_loss: 0.0814 - val_matthews_correlation: 0.8076
#
# Epoch 00033: val_matthews_correlation did not improve from 0.80929
# Epoch 34/50
# 2322/2322 [==============================] - 1s 511us/step - loss: 0.0949 - matthews_correlation: 0.6995 - val_loss: 0.0811 - val_matthews_correlation: 0.6930
#
# Epoch 00034: val_matthews_correlation did not improve from 0.80929
# Epoch 35/50
# 2322/2322 [==============================] - 1s 491us/step - loss: 0.0964 - matthews_correlation: 0.6573 - val_loss: 0.0829 - val_matthews_correlation: 0.6477
#
# Epoch 00035: val_matthews_correlation did not improve from 0.80929
# Epoch 36/50
# 2322/2322 [==============================] - 1s 490us/step - loss: 0.0949 - matthews_correlation: 0.7076 - val_loss: 0.0802 - val_matthews_correlation: 0.7457
#
# Epoch 00036: val_matthews_correlation did not improve from 0.80929
# Epoch 37/50
# 2322/2322 [==============================] - 1s 470us/step - loss: 0.1026 - matthews_correlation: 0.6480 - val_loss: 0.0861 - val_matthews_correlation: 0.6741
#
# Epoch 00037: val_matthews_correlation did not improve from 0.80929
# Epoch 38/50
# 2322/2322 [==============================] - 1s 495us/step - loss: 0.0984 - matthews_correlation: 0.6605 - val_loss: 0.0833 - val_matthews_correlation: 0.7763
#
# Epoch 00038: val_matthews_correlation did not improve from 0.80929
# Epoch 39/50
# 2322/2322 [==============================] - 1s 485us/step - loss: 0.1056 - matthews_correlation: 0.6861 - val_loss: 0.0820 - val_matthews_correlation: 0.7425
#
# Epoch 00039: val_matthews_correlation did not improve from 0.80929
# Epoch 40/50
# 2322/2322 [==============================] - 1s 509us/step - loss: 0.1003 - matthews_correlation: 0.6848 - val_loss: 0.0768 - val_matthews_correlation: 0.6930
#
# Epoch 00040: val_matthews_correlation did not improve from 0.80929
# Epoch 41/50
# 2322/2322 [==============================] - 1s 511us/step - loss: 0.0896 - matthews_correlation: 0.6808 - val_loss: 0.0768 - val_matthews_correlation: 0.6930
#
# Epoch 00041: val_matthews_correlation did not improve from 0.80929
# Epoch 42/50
# 2322/2322 [==============================] - 1s 471us/step - loss: 0.0928 - matthews_correlation: 0.7207 - val_loss: 0.0812 - val_matthews_correlation: 0.7351
#
# Epoch 00042: val_matthews_correlation did not improve from 0.80929
# Epoch 43/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.0884 - matthews_correlation: 0.6920 - val_loss: 0.0901 - val_matthews_correlation: 0.7982
#
# Epoch 00043: val_matthews_correlation did not improve from 0.80929
# Epoch 44/50
# 2322/2322 [==============================] - 1s 508us/step - loss: 0.1082 - matthews_correlation: 0.6673 - val_loss: 0.1336 - val_matthews_correlation: 0.7001
#
# Epoch 00044: val_matthews_correlation did not improve from 0.80929
# Epoch 45/50
# 2322/2322 [==============================] - 1s 489us/step - loss: 0.1090 - matthews_correlation: 0.6535 - val_loss: 0.0820 - val_matthews_correlation: 0.7312
#
# Epoch 00045: val_matthews_correlation did not improve from 0.80929
# Epoch 46/50
# 2322/2322 [==============================] - 1s 540us/step - loss: 0.0970 - matthews_correlation: 0.6645 - val_loss: 0.0869 - val_matthews_correlation: 0.7660
#
# Epoch 00046: val_matthews_correlation did not improve from 0.80929
# Epoch 47/50
# 2322/2322 [==============================] - 1s 530us/step - loss: 0.0876 - matthews_correlation: 0.7070 - val_loss: 0.0786 - val_matthews_correlation: 0.7543
#
# Epoch 00047: val_matthews_correlation did not improve from 0.80929
# Epoch 48/50
# 2322/2322 [==============================] - 1s 480us/step - loss: 0.0913 - matthews_correlation: 0.6563 - val_loss: 0.0787 - val_matthews_correlation: 0.7327
#
# Epoch 00048: val_matthews_correlation did not improve from 0.80929
# Epoch 49/50
# 2322/2322 [==============================] - 1s 476us/step - loss: 0.0917 - matthews_correlation: 0.6493 - val_loss: 0.0835 - val_matthews_correlation: 0.7317
#
# Epoch 00049: val_matthews_correlation did not improve from 0.80929
# Epoch 50/50
# 2322/2322 [==============================] - 1s 513us/step - loss: 0.0977 - matthews_correlation: 0.6595 - val_loss: 0.0792 - val_matthews_correlation: 0.8072
#
# Epoch 00050: val_matthews_correlation did not improve from 0.80929
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 2s 906us/step - loss: 0.3576 - matthews_correlation: 0.0000e+00 - val_loss: 0.2325 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 554us/step - loss: 0.2256 - matthews_correlation: 0.0000e+00 - val_loss: 0.2256 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 1s 539us/step - loss: 0.2240 - matthews_correlation: 0.0000e+00 - val_loss: 0.2361 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 1s 526us/step - loss: 0.2091 - matthews_correlation: 0.0394 - val_loss: 0.2209 - val_matthews_correlation: 0.1034
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.10339, saving model to weights_1.h5
# Epoch 5/50
# 2323/2323 [==============================] - 1s 531us/step - loss: 0.1972 - matthews_correlation: 0.2132 - val_loss: 0.2031 - val_matthews_correlation: 0.1034
#
# Epoch 00005: val_matthews_correlation did not improve from 0.10339
# Epoch 6/50
# 2323/2323 [==============================] - 1s 515us/step - loss: 0.1816 - matthews_correlation: 0.3314 - val_loss: 0.1843 - val_matthews_correlation: 0.2093
#
# Epoch 00006: val_matthews_correlation improved from 0.10339 to 0.20927, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 541us/step - loss: 0.1773 - matthews_correlation: 0.3744 - val_loss: 0.1750 - val_matthews_correlation: 0.2759
#
# Epoch 00007: val_matthews_correlation improved from 0.20927 to 0.27586, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 1s 534us/step - loss: 0.1599 - matthews_correlation: 0.4396 - val_loss: 0.1499 - val_matthews_correlation: 0.2759
#
# Epoch 00008: val_matthews_correlation did not improve from 0.27586
# Epoch 9/50
# 2323/2323 [==============================] - 1s 526us/step - loss: 0.1342 - matthews_correlation: 0.5227 - val_loss: 0.1956 - val_matthews_correlation: 0.2759
#
# Epoch 00009: val_matthews_correlation did not improve from 0.27586
# Epoch 10/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.1426 - matthews_correlation: 0.5573 - val_loss: 0.1222 - val_matthews_correlation: 0.5405
#
# Epoch 00010: val_matthews_correlation improved from 0.27586 to 0.54053, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.1129 - matthews_correlation: 0.6516 - val_loss: 0.1212 - val_matthews_correlation: 0.6243
#
# Epoch 00011: val_matthews_correlation improved from 0.54053 to 0.62429, saving model to weights_1.h5
# Epoch 12/50
# 2323/2323 [==============================] - 1s 532us/step - loss: 0.1064 - matthews_correlation: 0.6455 - val_loss: 0.1235 - val_matthews_correlation: 0.5104
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62429
# Epoch 13/50
# 2323/2323 [==============================] - 1s 543us/step - loss: 0.1181 - matthews_correlation: 0.5148 - val_loss: 0.1153 - val_matthews_correlation: 0.5876
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62429
# Epoch 14/50
# 2323/2323 [==============================] - 1s 475us/step - loss: 0.1102 - matthews_correlation: 0.5196 - val_loss: 0.1151 - val_matthews_correlation: 0.6394
#
# Epoch 00014: val_matthews_correlation improved from 0.62429 to 0.63941, saving model to weights_1.h5
# Epoch 15/50
# 2323/2323 [==============================] - 1s 479us/step - loss: 0.1095 - matthews_correlation: 0.6184 - val_loss: 0.1224 - val_matthews_correlation: 0.6085
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63941
# Epoch 16/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.1028 - matthews_correlation: 0.6411 - val_loss: 0.1219 - val_matthews_correlation: 0.6229
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63941
# Epoch 17/50
# 2323/2323 [==============================] - 1s 509us/step - loss: 0.0962 - matthews_correlation: 0.7037 - val_loss: 0.1079 - val_matthews_correlation: 0.5913
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63941
# Epoch 18/50
# 2323/2323 [==============================] - 1s 528us/step - loss: 0.1002 - matthews_correlation: 0.6906 - val_loss: 0.1160 - val_matthews_correlation: 0.5746
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63941
# Epoch 19/50
# 2323/2323 [==============================] - 1s 479us/step - loss: 0.1018 - matthews_correlation: 0.6651 - val_loss: 0.1128 - val_matthews_correlation: 0.5880
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63941
# Epoch 20/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.1012 - matthews_correlation: 0.6774 - val_loss: 0.1122 - val_matthews_correlation: 0.6022
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63941
# Epoch 21/50
# 2323/2323 [==============================] - 1s 483us/step - loss: 0.0968 - matthews_correlation: 0.6893 - val_loss: 0.1216 - val_matthews_correlation: 0.5727
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63941
# Epoch 22/50
# 2323/2323 [==============================] - 1s 486us/step - loss: 0.0957 - matthews_correlation: 0.6871 - val_loss: 0.1078 - val_matthews_correlation: 0.6041
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63941
# Epoch 23/50
# 2323/2323 [==============================] - 1s 478us/step - loss: 0.0932 - matthews_correlation: 0.7122 - val_loss: 0.1110 - val_matthews_correlation: 0.6353
#
# Epoch 00023: val_matthews_correlation did not improve from 0.63941
# Epoch 24/50
# 2323/2323 [==============================] - 1s 480us/step - loss: 0.0979 - matthews_correlation: 0.6897 - val_loss: 0.1133 - val_matthews_correlation: 0.6288
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63941
# Epoch 25/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.0937 - matthews_correlation: 0.6870 - val_loss: 0.1172 - val_matthews_correlation: 0.6387
#
# Epoch 00025: val_matthews_correlation did not improve from 0.63941
# Epoch 26/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.0943 - matthews_correlation: 0.6984 - val_loss: 0.1117 - val_matthews_correlation: 0.6132
#
# Epoch 00026: val_matthews_correlation did not improve from 0.63941
# Epoch 27/50
# 2323/2323 [==============================] - 1s 520us/step - loss: 0.0958 - matthews_correlation: 0.7171 - val_loss: 0.1176 - val_matthews_correlation: 0.6050
#
# Epoch 00027: val_matthews_correlation did not improve from 0.63941
# Epoch 28/50
# 2323/2323 [==============================] - 1s 535us/step - loss: 0.0978 - matthews_correlation: 0.7063 - val_loss: 0.1080 - val_matthews_correlation: 0.5963
#
# Epoch 00028: val_matthews_correlation did not improve from 0.63941
# Epoch 29/50
# 2323/2323 [==============================] - 1s 514us/step - loss: 0.1005 - matthews_correlation: 0.6852 - val_loss: 0.1102 - val_matthews_correlation: 0.6658
#
# Epoch 00029: val_matthews_correlation improved from 0.63941 to 0.66578, saving model to weights_1.h5
# Epoch 30/50
# 2323/2323 [==============================] - 1s 513us/step - loss: 0.1058 - matthews_correlation: 0.6462 - val_loss: 0.1141 - val_matthews_correlation: 0.6072
#
# Epoch 00030: val_matthews_correlation did not improve from 0.66578
# Epoch 31/50
# 2323/2323 [==============================] - 1s 536us/step - loss: 0.0894 - matthews_correlation: 0.6652 - val_loss: 0.1162 - val_matthews_correlation: 0.6047
#
# Epoch 00031: val_matthews_correlation did not improve from 0.66578
# Epoch 32/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.0870 - matthews_correlation: 0.7330 - val_loss: 0.1107 - val_matthews_correlation: 0.6858
#
# Epoch 00032: val_matthews_correlation improved from 0.66578 to 0.68578, saving model to weights_1.h5
# Epoch 33/50
# 2323/2323 [==============================] - 1s 524us/step - loss: 0.0870 - matthews_correlation: 0.7045 - val_loss: 0.1106 - val_matthews_correlation: 0.6050
#
# Epoch 00033: val_matthews_correlation did not improve from 0.68578
# Epoch 34/50
# 2323/2323 [==============================] - 1s 525us/step - loss: 0.0880 - matthews_correlation: 0.7073 - val_loss: 0.1070 - val_matthews_correlation: 0.6752
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68578
# Epoch 35/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0937 - matthews_correlation: 0.6337 - val_loss: 0.1025 - val_matthews_correlation: 0.7001
#
# Epoch 00035: val_matthews_correlation improved from 0.68578 to 0.70007, saving model to weights_1.h5
# Epoch 36/50
# 2323/2323 [==============================] - 1s 479us/step - loss: 0.0839 - matthews_correlation: 0.6958 - val_loss: 0.1117 - val_matthews_correlation: 0.6115
#
# Epoch 00036: val_matthews_correlation did not improve from 0.70007
# Epoch 37/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0883 - matthews_correlation: 0.7255 - val_loss: 0.1145 - val_matthews_correlation: 0.5875
#
# Epoch 00037: val_matthews_correlation did not improve from 0.70007
# Epoch 38/50
# 2323/2323 [==============================] - 1s 527us/step - loss: 0.0800 - matthews_correlation: 0.7109 - val_loss: 0.1230 - val_matthews_correlation: 0.6025
#
# Epoch 00038: val_matthews_correlation did not improve from 0.70007
# Epoch 39/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0783 - matthews_correlation: 0.7495 - val_loss: 0.1037 - val_matthews_correlation: 0.6849
#
# Epoch 00039: val_matthews_correlation did not improve from 0.70007
# Epoch 40/50
# 2323/2323 [==============================] - 1s 504us/step - loss: 0.0942 - matthews_correlation: 0.6698 - val_loss: 0.1293 - val_matthews_correlation: 0.5844
#
# Epoch 00040: val_matthews_correlation did not improve from 0.70007
# Epoch 41/50
# 2323/2323 [==============================] - 1s 473us/step - loss: 0.0994 - matthews_correlation: 0.6925 - val_loss: 0.0980 - val_matthews_correlation: 0.6939
#
# Epoch 00041: val_matthews_correlation did not improve from 0.70007
# Epoch 42/50
# 2323/2323 [==============================] - 1s 479us/step - loss: 0.0979 - matthews_correlation: 0.6709 - val_loss: 0.1025 - val_matthews_correlation: 0.6185
#
# Epoch 00042: val_matthews_correlation did not improve from 0.70007
# Epoch 43/50
# 2323/2323 [==============================] - 1s 475us/step - loss: 0.0836 - matthews_correlation: 0.7025 - val_loss: 0.1027 - val_matthews_correlation: 0.6836
#
# Epoch 00043: val_matthews_correlation did not improve from 0.70007
# Epoch 44/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0803 - matthews_correlation: 0.7067 - val_loss: 0.1050 - val_matthews_correlation: 0.6369
#
# Epoch 00044: val_matthews_correlation did not improve from 0.70007
# Epoch 45/50
# 2323/2323 [==============================] - 1s 513us/step - loss: 0.0795 - matthews_correlation: 0.6996 - val_loss: 0.1118 - val_matthews_correlation: 0.6260
#
# Epoch 00045: val_matthews_correlation did not improve from 0.70007
# Epoch 46/50
# 2323/2323 [==============================] - 1s 527us/step - loss: 0.0846 - matthews_correlation: 0.7330 - val_loss: 0.1172 - val_matthews_correlation: 0.6336
#
# Epoch 00046: val_matthews_correlation did not improve from 0.70007
# Epoch 47/50
# 2323/2323 [==============================] - 1s 543us/step - loss: 0.0871 - matthews_correlation: 0.7200 - val_loss: 0.1154 - val_matthews_correlation: 0.5940
#
# Epoch 00047: val_matthews_correlation did not improve from 0.70007
# Epoch 48/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0822 - matthews_correlation: 0.7029 - val_loss: 0.0963 - val_matthews_correlation: 0.6696
#
# Epoch 00048: val_matthews_correlation did not improve from 0.70007
# Epoch 49/50
# 2323/2323 [==============================] - 1s 495us/step - loss: 0.0847 - matthews_correlation: 0.7222 - val_loss: 0.1086 - val_matthews_correlation: 0.6781
#
# Epoch 00049: val_matthews_correlation did not improve from 0.70007
# Epoch 50/50
# 2323/2323 [==============================] - 1s 522us/step - loss: 0.0786 - matthews_correlation: 0.7629 - val_loss: 0.0978 - val_matthews_correlation: 0.6948
#
# Epoch 00050: val_matthews_correlation did not improve from 0.70007
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 2s 945us/step - loss: 0.3501 - matthews_correlation: 0.0000e+00 - val_loss: 0.2328 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 538us/step - loss: 0.2280 - matthews_correlation: 0.0000e+00 - val_loss: 0.2156 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 1s 496us/step - loss: 0.2157 - matthews_correlation: -0.0011 - val_loss: 0.2028 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.2086 - matthews_correlation: 0.0000e+00 - val_loss: 0.1985 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2323/2323 [==============================] - 1s 484us/step - loss: 0.1884 - matthews_correlation: 0.2637 - val_loss: 0.4663 - val_matthews_correlation: 0.0849
#
# Epoch 00005: val_matthews_correlation improved from 0.00000 to 0.08486, saving model to weights_2.h5
# Epoch 6/50
# 2323/2323 [==============================] - 1s 503us/step - loss: 0.2614 - matthews_correlation: 0.0131 - val_loss: 0.2231 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.08486
# Epoch 7/50
# 2323/2323 [==============================] - 1s 500us/step - loss: 0.2093 - matthews_correlation: 0.0000e+00 - val_loss: 0.1898 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.08486
# Epoch 8/50
# 2323/2323 [==============================] - 1s 524us/step - loss: 0.1873 - matthews_correlation: 0.0000e+00 - val_loss: 0.2157 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00008: val_matthews_correlation did not improve from 0.08486
# Epoch 9/50
# 2323/2323 [==============================] - 1s 550us/step - loss: 0.1918 - matthews_correlation: 0.0000e+00 - val_loss: 0.1869 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.08486
# Epoch 10/50
# 2323/2323 [==============================] - 1s 499us/step - loss: 0.1842 - matthews_correlation: 0.1243 - val_loss: 0.1981 - val_matthews_correlation: 0.3051
#
# Epoch 00010: val_matthews_correlation improved from 0.08486 to 0.30512, saving model to weights_2.h5
# Epoch 11/50
# 2323/2323 [==============================] - 1s 534us/step - loss: 0.1879 - matthews_correlation: 0.2861 - val_loss: 0.1640 - val_matthews_correlation: 0.3564
#
# Epoch 00011: val_matthews_correlation improved from 0.30512 to 0.35638, saving model to weights_2.h5
# Epoch 12/50
# 2323/2323 [==============================] - 1s 515us/step - loss: 0.1519 - matthews_correlation: 0.3313 - val_loss: 0.1932 - val_matthews_correlation: 0.4577
#
# Epoch 00012: val_matthews_correlation improved from 0.35638 to 0.45772, saving model to weights_2.h5
# Epoch 13/50
# 2323/2323 [==============================] - 1s 511us/step - loss: 0.1283 - matthews_correlation: 0.5781 - val_loss: 0.1247 - val_matthews_correlation: 0.5781
#
# Epoch 00013: val_matthews_correlation improved from 0.45772 to 0.57806, saving model to weights_2.h5
# Epoch 14/50
# 2323/2323 [==============================] - 1s 512us/step - loss: 0.1537 - matthews_correlation: 0.4291 - val_loss: 0.1457 - val_matthews_correlation: 0.3764
#
# Epoch 00014: val_matthews_correlation did not improve from 0.57806
# Epoch 15/50
# 2323/2323 [==============================] - 1s 523us/step - loss: 0.1275 - matthews_correlation: 0.3760 - val_loss: 0.1289 - val_matthews_correlation: 0.3405
#
# Epoch 00015: val_matthews_correlation did not improve from 0.57806
# Epoch 16/50
# 2323/2323 [==============================] - 1s 510us/step - loss: 0.1182 - matthews_correlation: 0.5761 - val_loss: 0.1394 - val_matthews_correlation: 0.3766
#
# Epoch 00016: val_matthews_correlation did not improve from 0.57806
# Epoch 17/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.1076 - matthews_correlation: 0.6110 - val_loss: 0.1189 - val_matthews_correlation: 0.5693
#
# Epoch 00017: val_matthews_correlation did not improve from 0.57806
# Epoch 18/50
# 2323/2323 [==============================] - 1s 501us/step - loss: 0.0984 - matthews_correlation: 0.6737 - val_loss: 0.1201 - val_matthews_correlation: 0.5821
#
# Epoch 00018: val_matthews_correlation improved from 0.57806 to 0.58214, saving model to weights_2.h5
# Epoch 19/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.1039 - matthews_correlation: 0.6396 - val_loss: 0.1203 - val_matthews_correlation: 0.5966
#
# Epoch 00019: val_matthews_correlation improved from 0.58214 to 0.59664, saving model to weights_2.h5
# Epoch 20/50
# 2323/2323 [==============================] - 1s 517us/step - loss: 0.0966 - matthews_correlation: 0.6894 - val_loss: 0.1191 - val_matthews_correlation: 0.5333
#
# Epoch 00020: val_matthews_correlation did not improve from 0.59664
# Epoch 21/50
# 2323/2323 [==============================] - 1s 546us/step - loss: 0.0958 - matthews_correlation: 0.6240 - val_loss: 0.1172 - val_matthews_correlation: 0.5926
#
# Epoch 00021: val_matthews_correlation did not improve from 0.59664
# Epoch 22/50
# 2323/2323 [==============================] - 1s 531us/step - loss: 0.0956 - matthews_correlation: 0.6996 - val_loss: 0.1248 - val_matthews_correlation: 0.5525
#
# Epoch 00022: val_matthews_correlation did not improve from 0.59664
# Epoch 23/50
# 2323/2323 [==============================] - 1s 523us/step - loss: 0.0990 - matthews_correlation: 0.6916 - val_loss: 0.1210 - val_matthews_correlation: 0.5757
#
# Epoch 00023: val_matthews_correlation did not improve from 0.59664
# Epoch 24/50
# 2323/2323 [==============================] - 1s 555us/step - loss: 0.0919 - matthews_correlation: 0.6915 - val_loss: 0.1183 - val_matthews_correlation: 0.5918
#
# Epoch 00024: val_matthews_correlation did not improve from 0.59664
# Epoch 25/50
# 2323/2323 [==============================] - 1s 540us/step - loss: 0.0898 - matthews_correlation: 0.7404 - val_loss: 0.1277 - val_matthews_correlation: 0.6134
#
# Epoch 00025: val_matthews_correlation improved from 0.59664 to 0.61345, saving model to weights_2.h5
# Epoch 26/50
# 2323/2323 [==============================] - 1s 521us/step - loss: 0.0957 - matthews_correlation: 0.6735 - val_loss: 0.1120 - val_matthews_correlation: 0.5829
#
# Epoch 00026: val_matthews_correlation did not improve from 0.61345
# Epoch 27/50
# 2323/2323 [==============================] - 1s 556us/step - loss: 0.0910 - matthews_correlation: 0.7481 - val_loss: 0.1142 - val_matthews_correlation: 0.5917
#
# Epoch 00027: val_matthews_correlation did not improve from 0.61345
# Epoch 28/50
# 2323/2323 [==============================] - 1s 531us/step - loss: 0.0915 - matthews_correlation: 0.7274 - val_loss: 0.1266 - val_matthews_correlation: 0.4600
#
# Epoch 00028: val_matthews_correlation did not improve from 0.61345
# Epoch 29/50
# 2323/2323 [==============================] - 1s 525us/step - loss: 0.0904 - matthews_correlation: 0.6949 - val_loss: 0.1179 - val_matthews_correlation: 0.6220
#
# Epoch 00029: val_matthews_correlation improved from 0.61345 to 0.62196, saving model to weights_2.h5
# Epoch 30/50
# 2323/2323 [==============================] - 1s 533us/step - loss: 0.0906 - matthews_correlation: 0.6765 - val_loss: 0.1167 - val_matthews_correlation: 0.5867
#
# Epoch 00030: val_matthews_correlation did not improve from 0.62196
# Epoch 31/50
# 2323/2323 [==============================] - 1s 564us/step - loss: 0.0934 - matthews_correlation: 0.6929 - val_loss: 0.1191 - val_matthews_correlation: 0.6285
#
# Epoch 00031: val_matthews_correlation improved from 0.62196 to 0.62847, saving model to weights_2.h5
# Epoch 32/50
# 2323/2323 [==============================] - 1s 529us/step - loss: 0.0888 - matthews_correlation: 0.7435 - val_loss: 0.1116 - val_matthews_correlation: 0.6361
#
# Epoch 00032: val_matthews_correlation improved from 0.62847 to 0.63608, saving model to weights_2.h5
# Epoch 33/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0875 - matthews_correlation: 0.7308 - val_loss: 0.1189 - val_matthews_correlation: 0.5921
#
# Epoch 00033: val_matthews_correlation did not improve from 0.63608
# Epoch 34/50
# 2323/2323 [==============================] - 1s 514us/step - loss: 0.0858 - matthews_correlation: 0.7320 - val_loss: 0.1185 - val_matthews_correlation: 0.6118
#
# Epoch 00034: val_matthews_correlation did not improve from 0.63608
# Epoch 35/50
# 2323/2323 [==============================] - 1s 529us/step - loss: 0.1085 - matthews_correlation: 0.6737 - val_loss: 0.1151 - val_matthews_correlation: 0.5761
#
# Epoch 00035: val_matthews_correlation did not improve from 0.63608
# Epoch 36/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0980 - matthews_correlation: 0.6406 - val_loss: 0.1877 - val_matthews_correlation: 0.0638
#
# Epoch 00036: val_matthews_correlation did not improve from 0.63608
# Epoch 37/50
# 2323/2323 [==============================] - 1s 484us/step - loss: 0.1232 - matthews_correlation: 0.5037 - val_loss: 0.1190 - val_matthews_correlation: 0.6535
#
# Epoch 00037: val_matthews_correlation improved from 0.63608 to 0.65352, saving model to weights_2.h5
# Epoch 38/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.1063 - matthews_correlation: 0.6459 - val_loss: 0.1164 - val_matthews_correlation: 0.6112
#
# Epoch 00038: val_matthews_correlation did not improve from 0.65352
# Epoch 39/50
# 2323/2323 [==============================] - 1s 507us/step - loss: 0.0960 - matthews_correlation: 0.6495 - val_loss: 0.1163 - val_matthews_correlation: 0.5631
#
# Epoch 00039: val_matthews_correlation did not improve from 0.65352
# Epoch 40/50
# 2323/2323 [==============================] - 1s 531us/step - loss: 0.0992 - matthews_correlation: 0.6871 - val_loss: 0.1126 - val_matthews_correlation: 0.6407
#
# Epoch 00040: val_matthews_correlation did not improve from 0.65352
# Epoch 41/50
# 2323/2323 [==============================] - 1s 517us/step - loss: 0.0941 - matthews_correlation: 0.6971 - val_loss: 0.1115 - val_matthews_correlation: 0.5464
#
# Epoch 00041: val_matthews_correlation did not improve from 0.65352
# Epoch 42/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0886 - matthews_correlation: 0.7029 - val_loss: 0.1157 - val_matthews_correlation: 0.6435
#
# Epoch 00042: val_matthews_correlation did not improve from 0.65352
# Epoch 43/50
# 2323/2323 [==============================] - 1s 516us/step - loss: 0.0997 - matthews_correlation: 0.6743 - val_loss: 0.1169 - val_matthews_correlation: 0.6311
#
# Epoch 00043: val_matthews_correlation did not improve from 0.65352
# Epoch 44/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0963 - matthews_correlation: 0.6788 - val_loss: 0.1115 - val_matthews_correlation: 0.6390
#
# Epoch 00044: val_matthews_correlation did not improve from 0.65352
# Epoch 45/50
# 2323/2323 [==============================] - 1s 506us/step - loss: 0.0921 - matthews_correlation: 0.6378 - val_loss: 0.1120 - val_matthews_correlation: 0.6301
#
# Epoch 00045: val_matthews_correlation did not improve from 0.65352
# Epoch 46/50
# 2323/2323 [==============================] - 1s 482us/step - loss: 0.0905 - matthews_correlation: 0.6696 - val_loss: 0.1101 - val_matthews_correlation: 0.5979
#
# Epoch 00046: val_matthews_correlation did not improve from 0.65352
# Epoch 47/50
# 2323/2323 [==============================] - 1s 479us/step - loss: 0.0849 - matthews_correlation: 0.7093 - val_loss: 0.1114 - val_matthews_correlation: 0.6234
#
# Epoch 00047: val_matthews_correlation did not improve from 0.65352
# Epoch 48/50
# 2323/2323 [==============================] - 1s 473us/step - loss: 0.0844 - matthews_correlation: 0.7319 - val_loss: 0.1169 - val_matthews_correlation: 0.5233
#
# Epoch 00048: val_matthews_correlation did not improve from 0.65352
# Epoch 49/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0882 - matthews_correlation: 0.6459 - val_loss: 0.1131 - val_matthews_correlation: 0.6068
#
# Epoch 00049: val_matthews_correlation did not improve from 0.65352
# Epoch 50/50
# 2323/2323 [==============================] - 1s 474us/step - loss: 0.0840 - matthews_correlation: 0.7084 - val_loss: 0.1073 - val_matthews_correlation: 0.6032
#
# Epoch 00050: val_matthews_correlation did not improve from 0.65352
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 2s 943us/step - loss: 0.3447 - matthews_correlation: 9.3723e-05 - val_loss: 0.2361 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 530us/step - loss: 0.2334 - matthews_correlation: 0.0000e+00 - val_loss: 0.2309 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 1s 486us/step - loss: 0.2256 - matthews_correlation: 0.0000e+00 - val_loss: 0.2286 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 1s 519us/step - loss: 0.2177 - matthews_correlation: 0.0000e+00 - val_loss: 0.2008 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 1s 520us/step - loss: 0.1886 - matthews_correlation: 0.0000e+00 - val_loss: 0.1763 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.2326 - matthews_correlation: 0.0443 - val_loss: 0.2211 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2324/2324 [==============================] - 1s 546us/step - loss: 0.2222 - matthews_correlation: 0.0000e+00 - val_loss: 0.2099 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.00000
# Epoch 8/50
# 2324/2324 [==============================] - 1s 527us/step - loss: 0.2091 - matthews_correlation: 0.0000e+00 - val_loss: 0.2005 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00008: val_matthews_correlation did not improve from 0.00000
# Epoch 9/50
# 2324/2324 [==============================] - 1s 519us/step - loss: 0.1970 - matthews_correlation: 0.0000e+00 - val_loss: 0.1753 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00009: val_matthews_correlation did not improve from 0.00000
# Epoch 10/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.1897 - matthews_correlation: 0.2107 - val_loss: 0.1679 - val_matthews_correlation: 0.2530
#
# Epoch 00010: val_matthews_correlation improved from 0.00000 to 0.25301, saving model to weights_3.h5
# Epoch 11/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.1667 - matthews_correlation: 0.2611 - val_loss: 0.1536 - val_matthews_correlation: 0.0725
#
# Epoch 00011: val_matthews_correlation did not improve from 0.25301
# Epoch 12/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.1688 - matthews_correlation: 0.0737 - val_loss: 0.1511 - val_matthews_correlation: 0.2530
#
# Epoch 00012: val_matthews_correlation did not improve from 0.25301
# Epoch 13/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.1495 - matthews_correlation: 0.3095 - val_loss: 0.1273 - val_matthews_correlation: 0.4245
#
# Epoch 00013: val_matthews_correlation improved from 0.25301 to 0.42449, saving model to weights_3.h5
# Epoch 14/50
# 2324/2324 [==============================] - 1s 478us/step - loss: 0.1177 - matthews_correlation: 0.6294 - val_loss: 0.1196 - val_matthews_correlation: 0.4779
#
# Epoch 00014: val_matthews_correlation improved from 0.42449 to 0.47795, saving model to weights_3.h5
# Epoch 15/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.1122 - matthews_correlation: 0.6432 - val_loss: 0.1107 - val_matthews_correlation: 0.6253
#
# Epoch 00015: val_matthews_correlation improved from 0.47795 to 0.62527, saving model to weights_3.h5
# Epoch 16/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.1062 - matthews_correlation: 0.6351 - val_loss: 0.1112 - val_matthews_correlation: 0.5698
#
# Epoch 00016: val_matthews_correlation did not improve from 0.62527
# Epoch 17/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.1021 - matthews_correlation: 0.6791 - val_loss: 0.1160 - val_matthews_correlation: 0.6546
#
# Epoch 00017: val_matthews_correlation improved from 0.62527 to 0.65457, saving model to weights_3.h5
# Epoch 18/50
# 2324/2324 [==============================] - 1s 494us/step - loss: 0.1134 - matthews_correlation: 0.6392 - val_loss: 0.1436 - val_matthews_correlation: 0.4297
#
# Epoch 00018: val_matthews_correlation did not improve from 0.65457
# Epoch 19/50
# 2324/2324 [==============================] - 1s 487us/step - loss: 0.1121 - matthews_correlation: 0.6249 - val_loss: 0.1129 - val_matthews_correlation: 0.4779
#
# Epoch 00019: val_matthews_correlation did not improve from 0.65457
# Epoch 20/50
# 2324/2324 [==============================] - 1s 482us/step - loss: 0.1039 - matthews_correlation: 0.6522 - val_loss: 0.1202 - val_matthews_correlation: 0.4802
#
# Epoch 00020: val_matthews_correlation did not improve from 0.65457
# Epoch 21/50
# 2324/2324 [==============================] - 1s 481us/step - loss: 0.1154 - matthews_correlation: 0.6350 - val_loss: 0.1273 - val_matthews_correlation: 0.5290
#
# Epoch 00021: val_matthews_correlation did not improve from 0.65457
# Epoch 22/50
# 2324/2324 [==============================] - 1s 529us/step - loss: 0.1082 - matthews_correlation: 0.6564 - val_loss: 0.1172 - val_matthews_correlation: 0.5851
#
# Epoch 00022: val_matthews_correlation did not improve from 0.65457
# Epoch 23/50
# 2324/2324 [==============================] - 1s 519us/step - loss: 0.1033 - matthews_correlation: 0.6130 - val_loss: 0.1106 - val_matthews_correlation: 0.6057
#
# Epoch 00023: val_matthews_correlation did not improve from 0.65457
# Epoch 24/50
# 2324/2324 [==============================] - 1s 525us/step - loss: 0.1015 - matthews_correlation: 0.6933 - val_loss: 0.1138 - val_matthews_correlation: 0.5189
#
# Epoch 00024: val_matthews_correlation did not improve from 0.65457
# Epoch 25/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.1026 - matthews_correlation: 0.6210 - val_loss: 0.1199 - val_matthews_correlation: 0.5304
#
# Epoch 00025: val_matthews_correlation did not improve from 0.65457
# Epoch 26/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.1039 - matthews_correlation: 0.6588 - val_loss: 0.1091 - val_matthews_correlation: 0.5933
#
# Epoch 00026: val_matthews_correlation did not improve from 0.65457
# Epoch 27/50
# 2324/2324 [==============================] - 1s 533us/step - loss: 0.0975 - matthews_correlation: 0.6918 - val_loss: 0.1091 - val_matthews_correlation: 0.6413
#
# Epoch 00027: val_matthews_correlation did not improve from 0.65457
# Epoch 28/50
# 2324/2324 [==============================] - 1s 510us/step - loss: 0.0967 - matthews_correlation: 0.6628 - val_loss: 0.1092 - val_matthews_correlation: 0.6954
#
# Epoch 00028: val_matthews_correlation improved from 0.65457 to 0.69542, saving model to weights_3.h5
# Epoch 29/50
# 2324/2324 [==============================] - 1s 500us/step - loss: 0.0953 - matthews_correlation: 0.6760 - val_loss: 0.1063 - val_matthews_correlation: 0.6124
#
# Epoch 00029: val_matthews_correlation did not improve from 0.69542
# Epoch 30/50
# 2324/2324 [==============================] - 1s 484us/step - loss: 0.0923 - matthews_correlation: 0.6760 - val_loss: 0.1064 - val_matthews_correlation: 0.6091
#
# Epoch 00030: val_matthews_correlation did not improve from 0.69542
# Epoch 31/50
# 2324/2324 [==============================] - 1s 487us/step - loss: 0.0949 - matthews_correlation: 0.6638 - val_loss: 0.1179 - val_matthews_correlation: 0.7002
#
# Epoch 00031: val_matthews_correlation improved from 0.69542 to 0.70021, saving model to weights_3.h5
# Epoch 32/50
# 2324/2324 [==============================] - 1s 528us/step - loss: 0.1026 - matthews_correlation: 0.6863 - val_loss: 0.1054 - val_matthews_correlation: 0.6947
#
# Epoch 00032: val_matthews_correlation did not improve from 0.70021
# Epoch 33/50
# 2324/2324 [==============================] - 1s 497us/step - loss: 0.0945 - matthews_correlation: 0.6228 - val_loss: 0.1095 - val_matthews_correlation: 0.6669
#
# Epoch 00033: val_matthews_correlation did not improve from 0.70021
# Epoch 34/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0949 - matthews_correlation: 0.7136 - val_loss: 0.1063 - val_matthews_correlation: 0.6810
#
# Epoch 00034: val_matthews_correlation did not improve from 0.70021
# Epoch 35/50
# 2324/2324 [==============================] - 1s 533us/step - loss: 0.0932 - matthews_correlation: 0.6743 - val_loss: 0.1086 - val_matthews_correlation: 0.5570
#
# Epoch 00035: val_matthews_correlation did not improve from 0.70021
# Epoch 36/50
# 2324/2324 [==============================] - 1s 534us/step - loss: 0.0936 - matthews_correlation: 0.6234 - val_loss: 0.1092 - val_matthews_correlation: 0.5630
#
# Epoch 00036: val_matthews_correlation did not improve from 0.70021
# Epoch 37/50
# 2324/2324 [==============================] - 1s 524us/step - loss: 0.0921 - matthews_correlation: 0.6482 - val_loss: 0.1073 - val_matthews_correlation: 0.6631
#
# Epoch 00037: val_matthews_correlation did not improve from 0.70021
# Epoch 38/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0918 - matthews_correlation: 0.6654 - val_loss: 0.1070 - val_matthews_correlation: 0.6708
#
# Epoch 00038: val_matthews_correlation did not improve from 0.70021
# Epoch 39/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0883 - matthews_correlation: 0.6903 - val_loss: 0.1109 - val_matthews_correlation: 0.5329
#
# Epoch 00039: val_matthews_correlation did not improve from 0.70021
# Epoch 40/50
# 2324/2324 [==============================] - 1s 523us/step - loss: 0.0869 - matthews_correlation: 0.7040 - val_loss: 0.1097 - val_matthews_correlation: 0.4786
#
# Epoch 00040: val_matthews_correlation did not improve from 0.70021
# Epoch 41/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0875 - matthews_correlation: 0.7043 - val_loss: 0.1053 - val_matthews_correlation: 0.6947
#
# Epoch 00041: val_matthews_correlation did not improve from 0.70021
# Epoch 42/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.0843 - matthews_correlation: 0.7413 - val_loss: 0.1044 - val_matthews_correlation: 0.6185
#
# Epoch 00042: val_matthews_correlation did not improve from 0.70021
# Epoch 43/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0911 - matthews_correlation: 0.6941 - val_loss: 0.1081 - val_matthews_correlation: 0.5590
#
# Epoch 00043: val_matthews_correlation did not improve from 0.70021
# Epoch 44/50
# 2324/2324 [==============================] - 1s 515us/step - loss: 0.0914 - matthews_correlation: 0.6712 - val_loss: 0.1005 - val_matthews_correlation: 0.7112
#
# Epoch 00044: val_matthews_correlation improved from 0.70021 to 0.71119, saving model to weights_3.h5
# Epoch 45/50
# 2324/2324 [==============================] - 1s 516us/step - loss: 0.0854 - matthews_correlation: 0.7303 - val_loss: 0.1018 - val_matthews_correlation: 0.7260
#
# Epoch 00045: val_matthews_correlation improved from 0.71119 to 0.72601, saving model to weights_3.h5
# Epoch 46/50
# 2324/2324 [==============================] - 1s 512us/step - loss: 0.0844 - matthews_correlation: 0.6803 - val_loss: 0.1070 - val_matthews_correlation: 0.6669
#
# Epoch 00046: val_matthews_correlation did not improve from 0.72601
# Epoch 47/50
# 2324/2324 [==============================] - 1s 511us/step - loss: 0.1049 - matthews_correlation: 0.6369 - val_loss: 0.1032 - val_matthews_correlation: 0.5194
#
# Epoch 00047: val_matthews_correlation did not improve from 0.72601
# Epoch 48/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0928 - matthews_correlation: 0.7141 - val_loss: 0.1034 - val_matthews_correlation: 0.5150
#
# Epoch 00048: val_matthews_correlation did not improve from 0.72601
# Epoch 49/50
# 2324/2324 [==============================] - 1s 525us/step - loss: 0.0932 - matthews_correlation: 0.7472 - val_loss: 0.1032 - val_matthews_correlation: 0.6156
#
# Epoch 00049: val_matthews_correlation did not improve from 0.72601
# Epoch 50/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.0929 - matthews_correlation: 0.6878 - val_loss: 0.1020 - val_matthews_correlation: 0.6660
#
# Epoch 00050: val_matthews_correlation did not improve from 0.72601
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 2s 987us/step - loss: 0.3606 - matthews_correlation: 0.0000e+00 - val_loss: 0.2475 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 502us/step - loss: 0.2275 - matthews_correlation: 0.0000e+00 - val_loss: 0.2014 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 1s 535us/step - loss: 0.2093 - matthews_correlation: 0.0139 - val_loss: 0.1900 - val_matthews_correlation: 0.3887
#
# Epoch 00003: val_matthews_correlation improved from 0.00000 to 0.38873, saving model to weights_4.h5
# Epoch 4/50
# 2324/2324 [==============================] - 1s 550us/step - loss: 0.2010 - matthews_correlation: 0.0791 - val_loss: 0.1810 - val_matthews_correlation: 0.4175
#
# Epoch 00004: val_matthews_correlation improved from 0.38873 to 0.41752, saving model to weights_4.h5
# Epoch 5/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.1768 - matthews_correlation: 0.3407 - val_loss: 0.1692 - val_matthews_correlation: 0.4426
#
# Epoch 00005: val_matthews_correlation improved from 0.41752 to 0.44264, saving model to weights_4.h5
# Epoch 6/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.1567 - matthews_correlation: 0.2412 - val_loss: 0.1721 - val_matthews_correlation: 0.3516
#
# Epoch 00006: val_matthews_correlation did not improve from 0.44264
# Epoch 7/50
# 2324/2324 [==============================] - 1s 526us/step - loss: 0.1472 - matthews_correlation: 0.3166 - val_loss: 0.1536 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.44264
# Epoch 8/50
# 2324/2324 [==============================] - 1s 539us/step - loss: 0.1428 - matthews_correlation: 0.4750 - val_loss: 0.1609 - val_matthews_correlation: 0.5378
#
# Epoch 00008: val_matthews_correlation improved from 0.44264 to 0.53779, saving model to weights_4.h5
# Epoch 9/50
# 2324/2324 [==============================] - 1s 535us/step - loss: 0.1262 - matthews_correlation: 0.5121 - val_loss: 0.1390 - val_matthews_correlation: 0.5217
#
# Epoch 00009: val_matthews_correlation did not improve from 0.53779
# Epoch 10/50
# 2324/2324 [==============================] - 1s 519us/step - loss: 0.1021 - matthews_correlation: 0.6756 - val_loss: 0.1232 - val_matthews_correlation: 0.4987
#
# Epoch 00010: val_matthews_correlation did not improve from 0.53779
# Epoch 11/50
# 2324/2324 [==============================] - 1s 521us/step - loss: 0.1020 - matthews_correlation: 0.6312 - val_loss: 0.1250 - val_matthews_correlation: 0.5940
#
# Epoch 00011: val_matthews_correlation improved from 0.53779 to 0.59402, saving model to weights_4.h5
# Epoch 12/50
# 2324/2324 [==============================] - 1s 522us/step - loss: 0.1126 - matthews_correlation: 0.6421 - val_loss: 0.1171 - val_matthews_correlation: 0.6488
#
# Epoch 00012: val_matthews_correlation improved from 0.59402 to 0.64882, saving model to weights_4.h5
# Epoch 13/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0998 - matthews_correlation: 0.6619 - val_loss: 0.1194 - val_matthews_correlation: 0.4351
#
# Epoch 00013: val_matthews_correlation did not improve from 0.64882
# Epoch 14/50
# 2324/2324 [==============================] - 1s 508us/step - loss: 0.1003 - matthews_correlation: 0.5609 - val_loss: 0.1153 - val_matthews_correlation: 0.6135
#
# Epoch 00014: val_matthews_correlation did not improve from 0.64882
# Epoch 15/50
# 2324/2324 [==============================] - 1s 522us/step - loss: 0.0955 - matthews_correlation: 0.6143 - val_loss: 0.1124 - val_matthews_correlation: 0.5990
#
# Epoch 00015: val_matthews_correlation did not improve from 0.64882
# Epoch 16/50
# 2324/2324 [==============================] - 1s 474us/step - loss: 0.0968 - matthews_correlation: 0.6517 - val_loss: 0.1185 - val_matthews_correlation: 0.4523
#
# Epoch 00016: val_matthews_correlation did not improve from 0.64882
# Epoch 17/50
# 2324/2324 [==============================] - 1s 482us/step - loss: 0.0959 - matthews_correlation: 0.6687 - val_loss: 0.1202 - val_matthews_correlation: 0.5448
#
# Epoch 00017: val_matthews_correlation did not improve from 0.64882
# Epoch 18/50
# 2324/2324 [==============================] - 1s 481us/step - loss: 0.0905 - matthews_correlation: 0.7064 - val_loss: 0.1126 - val_matthews_correlation: 0.5415
#
# Epoch 00018: val_matthews_correlation did not improve from 0.64882
# Epoch 19/50
# 2324/2324 [==============================] - 1s 505us/step - loss: 0.0922 - matthews_correlation: 0.6685 - val_loss: 0.1239 - val_matthews_correlation: 0.4268
#
# Epoch 00019: val_matthews_correlation did not improve from 0.64882
# Epoch 20/50
# 2324/2324 [==============================] - 1s 528us/step - loss: 0.1005 - matthews_correlation: 0.5774 - val_loss: 0.1126 - val_matthews_correlation: 0.6133
#
# Epoch 00020: val_matthews_correlation did not improve from 0.64882
# Epoch 21/50
# 2324/2324 [==============================] - 1s 541us/step - loss: 0.1006 - matthews_correlation: 0.6465 - val_loss: 0.1162 - val_matthews_correlation: 0.5785
#
# Epoch 00021: val_matthews_correlation did not improve from 0.64882
# Epoch 22/50
# 2324/2324 [==============================] - 1s 496us/step - loss: 0.0967 - matthews_correlation: 0.6683 - val_loss: 0.1117 - val_matthews_correlation: 0.6602
#
# Epoch 00022: val_matthews_correlation improved from 0.64882 to 0.66025, saving model to weights_4.h5
# Epoch 23/50
# 2324/2324 [==============================] - 1s 524us/step - loss: 0.0931 - matthews_correlation: 0.6550 - val_loss: 0.1157 - val_matthews_correlation: 0.5663
#
# Epoch 00023: val_matthews_correlation did not improve from 0.66025
# Epoch 24/50
# 2324/2324 [==============================] - 1s 524us/step - loss: 0.0908 - matthews_correlation: 0.7164 - val_loss: 0.1266 - val_matthews_correlation: 0.4102
#
# Epoch 00024: val_matthews_correlation did not improve from 0.66025
# Epoch 25/50
# 2324/2324 [==============================] - 1s 504us/step - loss: 0.0923 - matthews_correlation: 0.7124 - val_loss: 0.1185 - val_matthews_correlation: 0.6381
#
# Epoch 00025: val_matthews_correlation did not improve from 0.66025
# Epoch 26/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0986 - matthews_correlation: 0.6792 - val_loss: 0.1121 - val_matthews_correlation: 0.5754
#
# Epoch 00026: val_matthews_correlation did not improve from 0.66025
# Epoch 27/50
# 2324/2324 [==============================] - 1s 496us/step - loss: 0.0944 - matthews_correlation: 0.6470 - val_loss: 0.1111 - val_matthews_correlation: 0.5801
#
# Epoch 00027: val_matthews_correlation did not improve from 0.66025
# Epoch 28/50
# 2324/2324 [==============================] - 1s 504us/step - loss: 0.0851 - matthews_correlation: 0.6938 - val_loss: 0.1156 - val_matthews_correlation: 0.6060
#
# Epoch 00028: val_matthews_correlation did not improve from 0.66025
# Epoch 29/50
# 2324/2324 [==============================] - 1s 543us/step - loss: 0.0910 - matthews_correlation: 0.6803 - val_loss: 0.1207 - val_matthews_correlation: 0.4565
#
# Epoch 00029: val_matthews_correlation did not improve from 0.66025
# Epoch 30/50
# 2324/2324 [==============================] - 1s 539us/step - loss: 0.0845 - matthews_correlation: 0.7151 - val_loss: 0.1151 - val_matthews_correlation: 0.6219
#
# Epoch 00030: val_matthews_correlation did not improve from 0.66025
# Epoch 31/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0856 - matthews_correlation: 0.6923 - val_loss: 0.1204 - val_matthews_correlation: 0.6266
#
# Epoch 00031: val_matthews_correlation did not improve from 0.66025
# Epoch 32/50
# 2324/2324 [==============================] - 1s 537us/step - loss: 0.0877 - matthews_correlation: 0.7179 - val_loss: 0.1137 - val_matthews_correlation: 0.5723
#
# Epoch 00032: val_matthews_correlation did not improve from 0.66025
# Epoch 33/50
# 2324/2324 [==============================] - 1s 507us/step - loss: 0.0868 - matthews_correlation: 0.6905 - val_loss: 0.1091 - val_matthews_correlation: 0.6434
#
# Epoch 00033: val_matthews_correlation did not improve from 0.66025
# Epoch 34/50
# 2324/2324 [==============================] - 1s 514us/step - loss: 0.0825 - matthews_correlation: 0.7358 - val_loss: 0.1064 - val_matthews_correlation: 0.6247
#
# Epoch 00034: val_matthews_correlation did not improve from 0.66025
# Epoch 35/50
# 2324/2324 [==============================] - 1s 544us/step - loss: 0.0805 - matthews_correlation: 0.7163 - val_loss: 0.1141 - val_matthews_correlation: 0.6055
#
# Epoch 00035: val_matthews_correlation did not improve from 0.66025
# Epoch 36/50
# 2324/2324 [==============================] - 1s 531us/step - loss: 0.0806 - matthews_correlation: 0.7718 - val_loss: 0.1107 - val_matthews_correlation: 0.6146
#
# Epoch 00036: val_matthews_correlation did not improve from 0.66025
# Epoch 37/50
# 2324/2324 [==============================] - 1s 544us/step - loss: 0.0793 - matthews_correlation: 0.7354 - val_loss: 0.1293 - val_matthews_correlation: 0.4352
#
# Epoch 00037: val_matthews_correlation did not improve from 0.66025
# Epoch 38/50
# 2324/2324 [==============================] - 1s 537us/step - loss: 0.0886 - matthews_correlation: 0.7045 - val_loss: 0.1352 - val_matthews_correlation: 0.4739
#
# Epoch 00038: val_matthews_correlation did not improve from 0.66025
# Epoch 39/50
# 2324/2324 [==============================] - 1s 526us/step - loss: 0.0800 - matthews_correlation: 0.7269 - val_loss: 0.1092 - val_matthews_correlation: 0.6250
#
# Epoch 00039: val_matthews_correlation did not improve from 0.66025
# Epoch 40/50
# 2324/2324 [==============================] - 1s 540us/step - loss: 0.1012 - matthews_correlation: 0.6459 - val_loss: 0.1229 - val_matthews_correlation: 0.2684
#
# Epoch 00040: val_matthews_correlation did not improve from 0.66025
# Epoch 41/50
# 2324/2324 [==============================] - 1s 524us/step - loss: 0.1133 - matthews_correlation: 0.5922 - val_loss: 0.1135 - val_matthews_correlation: 0.6056
#
# Epoch 00041: val_matthews_correlation did not improve from 0.66025
# Epoch 42/50
# 2324/2324 [==============================] - 1s 529us/step - loss: 0.0929 - matthews_correlation: 0.6953 - val_loss: 0.1140 - val_matthews_correlation: 0.6294
#
# Epoch 00042: val_matthews_correlation did not improve from 0.66025
# Epoch 43/50
# 2324/2324 [==============================] - 1s 543us/step - loss: 0.0916 - matthews_correlation: 0.6961 - val_loss: 0.1080 - val_matthews_correlation: 0.6608
#
# Epoch 00043: val_matthews_correlation improved from 0.66025 to 0.66079, saving model to weights_4.h5
# Epoch 44/50
# 2324/2324 [==============================] - 1s 513us/step - loss: 0.0900 - matthews_correlation: 0.7188 - val_loss: 0.1069 - val_matthews_correlation: 0.6301
#
# Epoch 00044: val_matthews_correlation did not improve from 0.66079
# Epoch 45/50
# 2324/2324 [==============================] - 1s 515us/step - loss: 0.0803 - matthews_correlation: 0.7202 - val_loss: 0.1020 - val_matthews_correlation: 0.6128
#
# Epoch 00045: val_matthews_correlation did not improve from 0.66079
# Epoch 46/50
# 2324/2324 [==============================] - 1s 515us/step - loss: 0.0829 - matthews_correlation: 0.7196 - val_loss: 0.1085 - val_matthews_correlation: 0.6180
#
# Epoch 00046: val_matthews_correlation did not improve from 0.66079
# Epoch 47/50
# 2324/2324 [==============================] - 1s 535us/step - loss: 0.0834 - matthews_correlation: 0.7122 - val_loss: 0.1046 - val_matthews_correlation: 0.6335
#
# Epoch 00047: val_matthews_correlation did not improve from 0.66079
# Epoch 48/50
# 2324/2324 [==============================] - 1s 528us/step - loss: 0.0825 - matthews_correlation: 0.7072 - val_loss: 0.1144 - val_matthews_correlation: 0.5331
#
# Epoch 00048: val_matthews_correlation did not improve from 0.66079
# Epoch 49/50
# 2324/2324 [==============================] - 1s 537us/step - loss: 0.0845 - matthews_correlation: 0.7188 - val_loss: 0.1000 - val_matthews_correlation: 0.6140
#
# Epoch 00049: val_matthews_correlation did not improve from 0.66079
# Epoch 50/50
# 2324/2324 [==============================] - 1s 509us/step - loss: 0.0793 - matthews_correlation: 0.7348 - val_loss: 0.1014 - val_matthews_correlation: 0.6324
#
# Epoch 00050: val_matthews_correlation did not improve from 0.66079
# ((2904,), (2904,))

# %%
# The output of this kernel must be binary (0 or 1), but the output of the NN Model is float (0 to 1).
# So, find the best threshold to convert float to binary is crucial to the result
# this piece of code is a function that evaluates all the possible thresholds from 0 to 1 by 0.01
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        #score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        score = K.eval(matthews_correlation(K.variable(y_true.astype(np.float64)), K.variable((y_proba > threshold).astype(np.float64))))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [01:02<00:00,  1.07it/s]

# %%
# %%time
# Now load the test data
# This first part is the meta data, not the main data, the measurements
meta_test = pd.read_csv('../data/metadata_test.csv')
# Out:
# CPU times: user 24 ms, sys: 0 ns, total: 24 ms
# Wall time: 25.1 ms

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
# %%time
# First we daclarete a series of parameters to initiate the loading of the main data
# it is too large, it is impossible to load in one time, so we are doing it in dividing in 10 parts
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../data/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [02:29<00:00, 13.64it/s]
# 100%|██████████| 2033/2033 [02:32<00:00, 13.37it/s]
# 100%|██████████| 2033/2033 [02:37<00:00, 12.04it/s]
# 100%|██████████| 2033/2033 [02:36<00:00, 12.99it/s]
# 100%|██████████| 2033/2033 [02:43<00:00, 12.36it/s]
# 100%|██████████| 2033/2033 [02:33<00:00, 12.31it/s]
# 100%|██████████| 2033/2033 [02:38<00:00, 12.83it/s]
# 100%|██████████| 2033/2033 [02:31<00:00, 13.75it/s]
# 100%|██████████| 2033/2033 [02:29<00:00, 13.94it/s]
# 100%|██████████| 2033/2033 [02:34<00:00, 13.91it/s]
# 100%|██████████| 7/7 [00:00<00:00,  9.01it/s]
# CPU times: user 28min 5s, sys: 1min 49s, total: 29min 55s
# Wall time: 26min 8s

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
submission = pd.read_csv('../data/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    print(pred.shape)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 1s 127us/step
# (6779, 1)
# 6779/6779 [==============================] - 1s 137us/step
# (6779, 1)
# 6779/6779 [==============================] - 1s 137us/step
# (6779, 1)
# 6779/6779 [==============================] - 1s 131us/step
# (6779, 1)
# 6779/6779 [==============================] - 1s 124us/step
# (6779, 1)

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0
